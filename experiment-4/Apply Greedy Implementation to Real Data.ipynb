# %%
from Bio import SeqIO
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %matplotlib inline

# %%
def greedy_partition(df, threshold):

    ignore_index = []
    tally_dict = {}

    debug=False

    for row_id in df.index:

        if debug:
            print(row_id)
            print(ignore_index)

        # if we've already assigned this index as a child, don't need to consider it's row
        if not(row_id in ignore_index):

            # get the full dataframe row for this sample
            this_row_init = df.loc[row_id]  

            # remove columns that are already children of other nodes
            this_row = this_row_init.drop(labels = ignore_index)  
            #print(this_row)
            if debug:
                print(this_row_init.shape)
                print(this_row.shape)

            # children of this node are those with values greather than the threshold...
            children = list(this_row[this_row > threshold].index)
            children_filtered = [i for i in children if i != row_id ] #...not inlucding the node name itself

            if debug:
                print("len of children_filtered: " + str(len(children_filtered)) + '\n\n')

            # add the node + children to the dictionary, 
            # then add node + children to the set to ignore in future iterations
            tally_dict[row_id] = children_filtered
            ignore_index += children_filtered
            ignore_index += [row_id]

    return(tally_dict)

# %%
# taxon-specific data dumps are downloaded from GenBank using the corresponding query, written to .fasta, 
# ... and put in a location available to this script

#this_dump = "moraxellacatarhalis_29497_dump"
this_dump = "candidaauris_498019_dump"
#this_dump = "rhinovirusc_463676_dump"
#this_dump = "chkv_txid37124_dump"

# %%
# Run Sourmash on the input fasta containing all accessions for that species

K = 31
ST = 1000
    
start = time.time()

! mkdir {this_dump}
! rm cmp*;
! rm *sig;
! sourmash sketch dna -p k={K},scaled={ST} --singleton {this_dump}.fasta;
! sourmash compare *.sig --containment -o {this_dump}/cmp.dist --csv {this_dump}/cmp.csv;
! mv {this_dump}.fasta.sig {this_dump}

end = time.time()
elapsed = end - start
# Out:
# mkdir: candidaauris_498019_dump: File exists
# zsh:1: no matches found: cmp*
# zsh:1: no matches found: *sig
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# computing signatures for files: candidaauris_498019_dump.fasta
# Computing a total of 1 signature(s) for each input.
# calculated 8585 signatures for 8585 sequences in candidaauris_498019_dump.fasta
# saved 8585 signature(s) to 'candidaauris_498019_dump.fasta.sig'. Note: signature license is CC0.
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 8585 signatures total.
#
# min similarity in matrix: 0.000
# saving labels to: candidaauris_498019_dump/cmp.dist.labels.txt
# saving comparison matrix to: candidaauris_498019_dump/cmp.dist
# WARNING: size estimation for at least one of these sketches may be inaccurate. ANI values will be set to 1 for these comparisons.

# %%
# Read in the sourmash results and apply greedy clustering to generate the clustered result
result_df = pd.read_csv(this_dump + "/cmp.csv")
result_df.index = result_df.columns
result_df.shape

result_dict = greedy_partition(result_df, .6) # do greedy clustering

# %%
# Write out the clustered result for inspection (via BLAST, etc)
len_of_key_pair = []
for key in result_dict:
    print(key)
    print(result_dict[key])
    print('\n')
    len_of_key_pair.append(len(result_dict[key]))
# Out:
# OQ513466.1 [Candida] auris isolate CAu10_KSU small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ513465.1 [Candida] auris isolate CAu9_KSU small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ513464.1 [Candida] auris isolate CAu8_KSU small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ513463.1 [Candida] auris isolate CAu7_KSU small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ513462.1 [Candida] auris isolate CAu6_KSU small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ288964.1 [Candida] auris strain IFRC2087 mitochondrion, complete genome
# ['OQ288963.1 [Candida] auris strain B12342 mitochondrion, complete genome', 'OQ288962.1 [Candida] auris strain B120378 mitochondrion, complete genome', 'OQ288961.1 [Candida] auris strain B11220 mitochondrion, complete genome', 'OQ288960.1 [Candida] auris strain B11205 mitochondrion, complete genome', 'CM036996.1 [Candida] auris strain L1537/2020 mitochondrion, complete sequence, whole genome shotgun sequence', 'CM034545.1 [Candida] auris strain CAU924/6920 mitochondrion, whole genome shotgun sequence', 'CP041142.2 [Candida] auris isolate A1 mitochondrion', 'CP068458.1 [Candida] auris strain BJCA001 mitochondrion, complete genome', 'NC_053321.1 [Candida] auris isolate B8441 mitochondrion, complete genome', 'CP061163.1 [Candida] auris strain CA-AM1 mitochondrion, complete genome', 'MT849287.1 [Candida] auris isolate B8441 mitochondrion, complete genome', 'AP018713.1 [Candida] auris JCM 15448 mitochondrial DNA, complete sequence', 'LGST01000028.1 [Candida] auris strain 6684 Scaffold28, whole genome shotgun sequence']
#
#
# OQ349558.1 [Candida] auris isolate CaurisPT large subunit ribosomal RNA gene, partial sequence
# []
#
#
# PA560869.1 WO 2022210708-A/26: Recombinant microorganism and production method of C6 compounds
# []
#
#
# OF368882.1 KR 1020220073327-A/43: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368881.1 KR 1020220073327-A/42: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368880.1 KR 1020220073327-A/41: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368879.1 KR 1020220073327-A/40: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368878.1 KR 1020220073327-A/39: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368877.1 KR 1020220073327-A/38: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368868.1 KR 1020220073327-A/29: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368867.1 KR 1020220073327-A/28: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368866.1 KR 1020220073327-A/27: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368853.1 KR 1020220073327-A/14: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368852.1 KR 1020220073327-A/13: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368851.1 KR 1020220073327-A/12: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368850.1 KR 1020220073327-A/11: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368849.1 KR 1020220073327-A/10: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368848.1 KR 1020220073327-A/9: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OF368847.1 KR 1020220073327-A/8: Primer set for multiplex loop-mediated isothermal amplification reaction for detection and identification of Candida albicans, Candida auris and Candida glabrata using fluorescent probe
# []
#
#
# OQ061458.1 [Candida] auris isolate 2525 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061457.1 [Candida] auris isolate 2502 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061456.1 [Candida] auris isolate 2501 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061455.1 [Candida] auris isolate 2419 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061454.1 [Candida] auris isolate 2254 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061453.1 [Candida] auris isolate 2199 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061452.1 [Candida] auris isolate 2460 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061451.1 [Candida] auris isolate 2393 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061450.1 [Candida] auris isolate 2409 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061449.1 [Candida] auris isolate 2404 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061448.1 [Candida] auris isolate 2403 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061447.1 [Candida] auris isolate 2400 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061446.1 [Candida] auris isolate 722 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061445.1 [Candida] auris isolate 721 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061444.1 [Candida] auris isolate 720 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061443.1 [Candida] auris isolate 653 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061442.1 [Candida] auris isolate 598 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061441.1 [Candida] auris isolate 597 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061440.1 [Candida] auris isolate 2407 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061439.1 [Candida] auris isolate 2402 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061438.1 [Candida] auris isolate 2401 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061437.1 [Candida] auris isolate 2200 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061436.1 [Candida] auris isolate 2183 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061435.1 [Candida] auris isolate 2182 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061434.1 [Candida] auris isolate 2181 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061433.1 [Candida] auris isolate 2152 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061432.1 [Candida] auris isolate 1929 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061431.1 [Candida] auris isolate 1928 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061430.1 [Candida] auris isolate 1927 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061429.1 [Candida] auris isolate 1926 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061428.1 [Candida] auris isolate 1925 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061427.1 [Candida] auris isolate 1924 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061426.1 [Candida] auris isolate 1922 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061425.1 [Candida] auris isolate 1921 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061424.1 [Candida] auris isolate 1920 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061423.1 [Candida] auris isolate 1919 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061422.1 [Candida] auris isolate 1917 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061421.1 [Candida] auris isolate 1915 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061420.1 [Candida] auris isolate 1901 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061419.1 [Candida] auris isolate 1897 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061418.1 [Candida] auris isolate 1892 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061417.1 [Candida] auris isolate 1891 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061416.1 [Candida] auris isolate 1773 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061415.1 [Candida] auris isolate 1717 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061414.1 [Candida] auris isolate 1642 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061413.1 [Candida] auris isolate 1639 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061412.1 [Candida] auris isolate 1555 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061411.1 [Candida] auris isolate 1541 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061410.1 [Candida] auris isolate 1412 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061409.1 [Candida] auris isolate 1383 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061408.1 [Candida] auris isolate 1381 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061407.1 [Candida] auris isolate 1011 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OQ061405.1 [Candida] auris isolate 2525 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061404.1 [Candida] auris isolate 2502 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061403.1 [Candida] auris isolate 2501 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061402.1 [Candida] auris isolate 2419 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061401.1 [Candida] auris isolate 2254 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061400.1 [Candida] auris isolate 2199 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061399.1 [Candida] auris isolate 2460 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061398.1 [Candida] auris isolate 2393 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061397.1 [Candida] auris isolate 2409 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061396.1 [Candida] auris isolate 2404 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061395.1 [Candida] auris isolate 2403 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061394.1 [Candida] auris isolate 2400 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061393.1 [Candida] auris isolate 2407 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061392.1 [Candida] auris isolate 2402 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061391.1 [Candida] auris isolate 2401 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061390.1 [Candida] auris isolate 2200 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061389.1 [Candida] auris isolate 2183 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061388.1 [Candida] auris isolate 2182 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061387.1 [Candida] auris isolate 2181 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061386.1 [Candida] auris isolate 2152 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061385.1 [Candida] auris isolate 722 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061384.1 [Candida] auris isolate 721 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061383.1 [Candida] auris isolate 720 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061382.1 [Candida] auris isolate 653 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061381.1 [Candida] auris isolate 598 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061380.1 [Candida] auris isolate 597 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061379.1 [Candida] auris isolate 1929 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061378.1 [Candida] auris isolate 1928 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061377.1 [Candida] auris isolate 1927 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061376.1 [Candida] auris isolate 1926 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061375.1 [Candida] auris isolate 1925 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061374.1 [Candida] auris isolate 1924 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061373.1 [Candida] auris isolate 1922 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061372.1 [Candida] auris isolate 1921 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061371.1 [Candida] auris isolate 1920 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061370.1 [Candida] auris isolate 1919 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061369.1 [Candida] auris isolate 1917 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061368.1 [Candida] auris isolate 1915 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061367.1 [Candida] auris isolate 1901 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061366.1 [Candida] auris isolate 1897 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061365.1 [Candida] auris isolate 1892 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061364.1 [Candida] auris isolate 1891 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061363.1 [Candida] auris isolate 1773 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061362.1 [Candida] auris isolate 1717 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061361.1 [Candida] auris isolate 1642 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061360.1 [Candida] auris isolate 1639 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061359.1 [Candida] auris isolate 1555 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061358.1 [Candida] auris isolate 1541 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061357.1 [Candida] auris isolate 1412 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061356.1 [Candida] auris isolate 1383 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061355.1 [Candida] auris isolate 1381 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OQ061354.1 [Candida] auris isolate 1011 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OP984818.1 [Candida] auris isolate 0579 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP984817.1 [Candida] auris isolate 21DY 278M00215 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# OP984816.1 [Candida] auris isolate 21UA 342M00567 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP984815.1 [Candida] auris isolate RN180001039 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP984814.1 [Candida] auris isolate RN190002998 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP974692.1 [Candida] auris strain Ath21 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP967937.1 [Candida] auris isolate FO-ca small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP066795.1 [Candida] auris microsatellite sequence
# []
#
#
# OP895145.1 [Candida] auris isolate MYC-97-22 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859130.1 [Candida] auris isolate MYC-57-22 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859129.1 [Candida] auris isolate MYC-82-21 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859128.1 [Candida] auris isolate MYC-67-21 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859127.1 [Candida] auris isolate MYC-97-22 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859126.1 [Candida] auris isolate MYC-43-21 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP859125.1 [Candida] auris isolate MYC-101-21 large subunit ribosomal RNA gene, partial sequence
# []
#
#
# OP776789.1 [Candida] auris strain ASM1 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# []
#
#
# LC736034.1 [Candida] auris CAS-3 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds
# []
#
#
# LC736033.1 [Candida] auris MFG-2 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds
# []
#
#
# LC736032.1 [Candida] auris CAS-4 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds
# []
#
#
# LC736031.1 [Candida] auris CAS-2 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds
# ['LC736030.1 [Candida] auris MFG-1 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds', 'LC736029.1 [Candida] auris CAS-1 FKS1 gene for 1,3-beta-D-glucan synthase, partial cds', 'OK646081.1 [Candida] auris isolate Kw2895/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646080.1 [Candida] auris isolate Kw2568/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646079.1 [Candida] auris isolate Kw1946/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646078.1 [Candida] auris isolate Kw2067/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646077.1 [Candida] auris isolate Kw1900/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646076.1 [Candida] auris isolate Kw1753/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646075.1 [Candida] auris isolate Kw1674/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646074.1 [Candida] auris isolate Kw1633/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646073.1 [Candida] auris isolate Kw782/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646072.1 [Candida] auris isolate Kw648/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646071.1 [Candida] auris isolate Kw349/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646070.1 [Candida] auris isolate Kw334/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646069.1 [Candida] auris isolate Kw281/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646068.1 [Candida] auris isolate Kw147/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646067.1 [Candida] auris isolate Kw340-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646066.1 [Candida] auris isolate Kw55-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646065.1 [Candida] auris isolate Kw8-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646064.1 [Candida] auris isolate Kw3134/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646063.1 [Candida] auris isolate Kw3092/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646062.1 [Candida] auris isolate Kw2989/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646061.1 [Candida] auris isolate Kw2968/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646060.1 [Candida] auris isolate Kw2611/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646059.1 [Candida] auris isolate Kw3521/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646058.1 [Candida] auris isolate Kw3424/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646057.1 [Candida] auris isolate Kw3367/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646056.1 [Candida] auris isolate Kw3135/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646055.1 [Candida] auris isolate Kw2871/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646054.1 [Candida] auris isolate Kw2647/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646053.1 [Candida] auris isolate Kw2609/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646052.1 [Candida] auris isolate Kw2501/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646051.1 [Candida] auris isolate Kw2742/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646050.1 [Candida] auris isolate Kw2713/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646049.1 [Candida] auris isolate Kw2260/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646048.1 [Candida] auris isolate Kw2074/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646047.1 [Candida] auris isolate Kw1994/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646046.1 [Candida] auris isolate Kw1893/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646045.1 [Candida] auris isolate Kw1856/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646044.1 [Candida] auris isolate Kw1825/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds', 'OK646043.1 [Candida] aur ...
#
#
# OK646130.1 [Candida] auris isolate Kw2895/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646129.1 [Candida] auris isolate Kw2568/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646128.1 [Candida] auris isolate Kw1946/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646127.1 [Candida] auris isolate Kw2067/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646126.1 [Candida] auris isolate Kw1900/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646125.1 [Candida] auris isolate Kw1753/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646124.1 [Candida] auris isolate Kw1674/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646123.1 [Candida] auris isolate Kw1633/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646122.1 [Candida] auris isolate Kw782/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646121.1 [Candida] auris isolate Kw648/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646120.1 [Candida] auris isolate Kw349/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646119.1 [Candida] auris isolate Kw334/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646118.1 [Candida] auris isolate Kw281/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646117.1 [Candida] auris isolate Kw147/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646116.1 [Candida] auris isolate Kw340-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646115.1 [Candida] auris isolate Kw55-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646114.1 [Candida] auris isolate Kw8-1/18 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646113.1 [Candida] auris isolate Kw3134/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646112.1 [Candida] auris isolate Kw3092/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646111.1 [Candida] auris isolate Kw2989/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646110.1 [Candida] auris isolate Kw2968/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646109.1 [Candida] auris isolate Kw2611/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646108.1 [Candida] auris isolate Kw3521/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646107.1 [Candida] auris isolate Kw3424/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646106.1 [Candida] auris isolate Kw3367/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646105.1 [Candida] auris isolate Kw3135/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646104.1 [Candida] auris isolate Kw2871/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646103.1 [Candida] auris isolate Kw2647/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646102.1 [Candida] auris isolate Kw2609/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646101.1 [Candida] auris isolate Kw2501/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646100.1 [Candida] auris isolate Kw2742/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646099.1 [Candida] auris isolate Kw2713/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646098.1 [Candida] auris isolate Kw2260/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646097.1 [Candida] auris isolate Kw2074/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646096.1 [Candida] auris isolate Kw1994/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646095.1 [Candida] auris isolate Kw1893/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646094.1 [Candida] auris isolate Kw1856/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646093.1 [Candida] auris isolate Kw1825/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646092.1 [Candida] auris isolate Kw1695/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646091.1 [Candida] auris isolate Kw1432/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646090.1 [Candida] auris isolate Kw2049/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646089.1 [Candida] auris isolate Kw2040/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646088.1 [Candida] auris isolate Kw2255/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646087.1 [Candida] auris isolate Kw2254/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646086.1 [Candida] auris isolate Kw2236/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646085.1 [Candida] auris isolate Kw2039/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646084.1 [Candida] auris isolate Kw2030/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646083.1 [Candida] auris isolate Kw2007/17 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OK646082.1 [Candida] auris isolate Kw1983/16 1,3-beta-D-glucan synthase (FKS1) gene, partial cds
# []
#
#
# OL539420.1 [Candida] auris RNA polymerase II largest subunit (RPB1) gene, partial cds
# ['ON287383.1 [Candida] auris DNA-directed RNA polymerase II subunit (RPB1) gene, partial cds', 'MW091411.1 [Candida] auris strain ZS RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MW091410.1 [Candida] auris strain RF RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MW091409.1 [Candida] auris strain 202629 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MW091408.1 [Candida] auris strain 202633 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MW091406.1 [Candida] auris strain 202630 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MW091401.1 [Candida] auris strain 202634 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294622.1 [Candida] auris isolate C3563 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294621.1 [Candida] auris isolate AR0390 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294620.1 [Candida] auris isolate AR0389 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294619.1 [Candida] auris isolate AR0388 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294618.1 [Candida] auris isolate AR0387 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294617.1 [Candida] auris isolate AR0386 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294616.1 [Candida] auris isolate AR0385 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294615.1 [Candida] auris isolate AR0384 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294614.1 [Candida] auris isolate AR0383 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294613.1 [Candida] auris isolate AR0382 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294612.1 [Candida] auris isolate AR0381 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK294611.1 [Candida] auris isolate R1C14317 RPB1 (RPB1) gene, partial cds', 'MK294610.1 [Candida] auris isolate R1C7591 RPB1 (RPB1) gene, partial cds', 'MK294609.1 [Candida] auris isolate R1C7374 RPB1 (RPB1) gene, partial cds', 'MK294608.1 [Candida] auris isolate R1C158 RPB1 (RPB1) gene, partial cds', 'MK308800.1 [Candida] auris isolate R1C14808 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308799.1 [Candida] auris isolate R1C15088 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308798.1 [Candida] auris isolate R1C15090 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308797.1 [Candida] auris isolate R1C14156 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308796.1 [Candida] auris isolate R1C14318 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308795.1 [Candida] auris isolate R1C13736 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308794.1 [Candida] auris isolate R1C11914 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308793.1 [Candida] auris isolate R1C11731 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308792.1 [Candida] auris isolate R1C6506 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308791.1 [Candida] auris isolate R1C6501 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308790.1 [Candida] auris isolate R1C6500 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308789.1 [Candida] auris isolate R1C4416 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308788.1 [Candida] auris isolate R1C4339 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308787.1 [Candida] auris isolate R1C4338 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308786.1 [Candida] auris isolate R1C4510 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308785.1 [Candida] auris isolate R1C4509 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308784.1 [Candida] auris isolate R1C4507 RNA polymerase II largest subunit (RPB1) gene, partial cds', 'MK308783.1 [Candida] auris isolate R1C3400 RNA polymer ...
#
#
# OK216333.1 [Candida] auris strain B8441 agglutinin-like sequence adhesin (CauALS4112) gene, complete cds
# ['XM_029036145.1 [Candida] auris uncharacterized protein (CJI97_004175), partial mRNA']
#
#
# OK216332.1 [Candida] auris strain B8441 agglutinin-like sequence adhesin (CauALS4498) gene, complete cds
# ['XM_029036904.1 [Candida] auris uncharacterized protein (CJI97_004954), partial mRNA']
#
#
# OK216331.1 [Candida] auris strain B8441 agglutinin-like sequence adhesin (CauALS2582) gene, complete cds
# []
#
#
# OK631933.1 [Candida] auris isolate GMCH_A06 14-alpha-demethylase (ERG11) gene, partial cds
# ['OK631932.1 [Candida] auris isolate GMCH_A04 14-alpha-demethylase (ERG11) gene, partial cds', 'OK631931.1 [Candida] auris isolate GMCH_A03 14-alpha-demethylase (ERG11) gene, partial cds', 'OK631930.1 [Candida] auris isolate GMCH_A02 14-alpha-demethylase (ERG11) gene, partial cds', 'OK631929.1 [Candida] auris isolate GMCH_A01 14-alpha-demethylase (ERG11) gene, partial cds', 'OK564652.1 [Candida] auris strain VPCI 717/P/14 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564651.1 [Candida] auris strain VPCI 471/P/13 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564650.1 [Candida] auris strain VPCI 669/P/12 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564647.1 [Candida] auris strain SA18 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564646.1 [Candida] auris strain SA1 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564645.1 [Candida] auris strain A3 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564644.1 [Candida] auris strain A1 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564641.1 [Candida] auris strain AR-1103 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564640.1 [Candida] auris strain AR-1102 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564639.1 [Candida] auris strain AR-1101 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564638.1 [Candida] auris strain AR-1100 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564637.1 [Candida] auris strain AR-1099 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564634.1 [Candida] auris strain AR-0390 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564633.1 [Candida] auris strain AR-0389 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564632.1 [Candida] auris strain AR-0388 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564631.1 [Candida] auris strain AR-0387 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564628.1 [Candida] auris strain AR-0384 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564627.1 [Candida] auris strain AR-0383 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564626.1 [Candida] auris strain AR-0382 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564625.1 [Candida] auris strain AR-0381 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'OK564624.1 [Candida] auris strain CBS 12372 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds', 'ON853793.1 [Candida] auris isolate CMMC 14-alpha-demethylase (ERG11) gene, partial cds', 'ON853792.1 [Candida] auris isolate KMUH 14-alpha-demethylase (ERG11) gene, partial cds', 'XM_029033208.1 [Candida] auris lanosterol 14-alpha demethylase (CJI97_001156), partial mRNA', 'OL742093.1 [Candida] auris strain III.9 Erg11 (ERG11) gene, complete cds', 'OL742092.1 [Candida] auris strain III.8 Erg11 (ERG11) gene, complete cds', 'OL742091.1 [Candida] auris strain III.7 Erg11 (ERG11) gene, complete cds', 'OM287083.1 [Candida] auris isolate Cauris_II.2 lanosterol 14-alpha demethylase (ERG11) gene, complete cds', 'OM287082.1 [Candida] auris isolate Cauris_II.1 lanosterol 14-alpha demethylase (ERG11) gene, complete cds', 'OM287081.1 [Candida] auris isolate Cauris_I.4 lanosterol 14-alpha demethylase (ERG11) gene, complete cds', 'OM287080.1 [Candida] auris isolate Cauris_I.3 lanosterol 14-alpha demethylase (ERG11) gene, complete cds', 'OM287079.1 [Candida] auris isolate Cauris_I.2 lanosterol 14-alpha demethylase (ERG11) gene, complete cds', 'MK059961.1 [Candida] auris isolate VPCI 1133/P/13-R 14-alpha-demethylase (ERG11) gene, partial cds', 'MK059960.1 [Candida] auris isolate VPCI 1132/P/13 14-alpha-demethylase (ERG11) gene, partial cds', 'MK059959.1 [Candida] auris strain CBS 10913 14-alpha-demethylase (ERG11) gene, complete cds', 'MW619634.1 [Candida] auris strain L1537 14-alpha-demethylase (ERG11) gene, partial cds', 'MK2 ...
#
#
# OK564654.1 [Candida] auris strain C76783 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564653.1 [Candida] auris strain 32101081 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564649.1 [Candida] auris strain SA24 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564648.1 [Candida] auris strain SA20 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564643.1 [Candida] auris strain AR-1105 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564642.1 [Candida] auris strain AR-1104 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564636.1 [Candida] auris strain AR-1097 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564635.1 [Candida] auris strain AR-0931 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564630.1 [Candida] auris strain AR-0386 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564629.1 [Candida] auris strain AR-0385 lanosterol 14-alpha-demethylase (ERG11) gene, complete cds
# []
#
#
# OK564623.1 [Candida] auris strain C76783 C-24 sterol methyltransferase (ERG6) gene, complete cds
# ['OK564622.1 [Candida] auris strain 32101081 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564621.1 [Candida] auris strain C54019 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564620.1 [Candida] auris strain C48374 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564619.1 [Candida] auris strain A106871 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564618.1 [Candida] auris strain 2324866 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564617.1 [Candida] auris strain VPCI 717/P/14 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564616.1 [Candida] auris strain VPCI 471/P/13 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564615.1 [Candida] auris strain VPCI 669/P/12 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564614.1 [Candida] auris strain SA24 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564613.1 [Candida] auris strain SA20 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564612.1 [Candida] auris strain SA18 C-24 sterol methyltransferase (ERG6) gene, partial cds', 'OK564611.1 [Candida] auris strain SA1 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564610.1 [Candida] auris strain A3 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564609.1 [Candida] auris strain A1 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564608.1 [Candida] auris strain AR-1105 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564607.1 [Candida] auris strain AR-1104 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564606.1 [Candida] auris strain AR-1103 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564605.1 [Candida] auris strain AR-1102 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564604.1 [Candida] auris strain AR-1101 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564603.1 [Candida] auris strain AR-1100 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564602.1 [Candida] auris strain AR-1099 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564601.1 [Candida] auris strain AR-1097 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564600.1 [Candida] auris strain AR-0931 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564599.1 [Candida] auris strain AR-0390 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564598.1 [Candida] auris strain AR-0389 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564597.1 [Candida] auris strain AR-0388 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564596.1 [Candida] auris strain AR-0387 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564595.1 [Candida] auris strain AR-0386 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564594.1 [Candida] auris strain AR-0385 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564593.1 [Candida] auris strain AR-0384 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564592.1 [Candida] auris strain AR-0383 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564591.1 [Candida] auris strain AR-0382 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564590.1 [Candida] auris strain AR-0381 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564589.1 [Candida] auris strain CBS 12372 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'OK564588.1 [Candida] auris strain CBS 10913 C-24 sterol methyltransferase (ERG6) gene, complete cds', 'XM_029037356.1 [Candida] auris sterol 24-C-methyltransferase (CJI97_005423), partial mRNA', 'MZ773955.1 Mutant [Candida] auris isolate 3_ERG6_WT clone B sterol-methyltransferase (ERG6) gene, complete cds', 'MZ773954.1 Mutant [Candida] auris isolate 3_ERG6_WT clone A sterol-methyltransferase (ERG6) gene, complete cds', 'MZ773953.1 Mutant [Candida] auris isolate 2_ERG6_WT clone B sterol-methyltransferase (ERG6) gene, complete cds', 'MZ773952.1 Mutant [Candida] aur ...
#
#
# OK564587.1 [Candida] auris strain C76783 C-5 sterol desaturase (ERG3) gene, complete cds
# ...
# []
#
#
# KP862776.1 Candida auris isolate VPCI 474/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862775.1 Candida auris isolate VPCI 473/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862774.1 Candida auris isolate VPCI 471/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862773.1 Candida auris isolate VPCI 470/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862772.1 Candida auris isolate VPCI 469/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862771.1 Candida auris isolate VPCI 468/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862770.1 Candida auris isolate VPCI 467/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862769.1 Candida auris isolate VPCI 464/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862768.1 Candida auris isolate VPCI 463/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862767.1 Candida auris isolate VPCI 462/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862766.1 Candida auris isolate VPCI 459/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862765.1 Candida auris isolate VPCI 271/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862764.1 Candida auris isolate VPCI 270/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862763.1 Candida auris isolate VPCI 266/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862762.1 Candida auris isolate VPCI 265/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862761.1 Candida auris isolate VPCI 264/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862760.1 Candida auris isolate VPCI 263/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862759.1 Candida auris isolate VPCI 261/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862758.1 Candida auris isolate VPCI 260/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862757.1 Candida auris isolate VPCI 253/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862756.1 Candida auris isolate VPCI 250/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862755.1 Candida auris isolate VPCI 249/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862754.1 Candida auris isolate VPCI 248/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862753.1 Candida auris isolate VPCI 247/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862752.1 Candida auris isolate VPCI 245/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862751.1 Candida auris isolate VPCI 107/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862750.1 Candida auris isolate VPCI 106/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862749.1 Candida auris isolate VPCI 105/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862748.1 Candida auris isolate VPCI 1133/P/13 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862747.1 Candida auris isolate VPCI 1132/P/13 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862746.1 Candida auris isolate VPCI 1131/P/13 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP862745.1 Candida auris isolate VPCI 1130/P/13 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP326583.1 Candida auris strain UZ1447_14 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KP131674.1 Candida auris strain CNRMA7.797 isolate ISHAM-ITS_ID MITS484 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# LN626311.1 Candida auris partial 28S rRNA gene, strain Kw1732-14
# []
#
#
# LN624638.1 Candida auris genomic DNA sequence contains 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2, 28S rRNA gene, strain Kw1732-14
# []
#
#
# KM000830.1 Candida auris isolate VPCI_107/P/14 28S large subunit ribosomal RNA gene, partial sequence
# []
#
#
# KM000829.1 Candida auris isolate VPCI_106/P/14 28S large subunit ribosomal RNA gene, partial sequence
# []
#
#
# KM000828.1 Candida auris isolate VPCI_105/P/14 28S large subunit ribosomal RNA gene, partial sequence
# []
#
#
# KM000827.1 Candida auris isolate VPCI_107/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KM000826.1 Candida auris isolate VPCI_106/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KM000825.1 Candida auris isolate VPCI_105/P/14 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126765.1 Candida auris strain MRL293 26S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126764.1 Candida auris strain MRL224 26S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126763.1 Candida auris strain MRL209 26S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126762.1 Candida auris strain MRL208 26S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126761.1 Candida auris strain MRL293 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126760.1 Candida auris strain MRL224 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126759.1 Candida auris strain MRL209 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KJ126758.1 Candida auris strain MRL208 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692066.1 Candida auris isolate VPCI_712/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692065.1 Candida auris isolate VPCI_671/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692064.1 Candida auris isolate VPCI_692/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692063.1 Candida auris isolate VPCI_683/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692062.1 Candida auris isolate VPCI_711/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692061.1 Candida auris isolate VPCI_709/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692060.1 Candida auris isolate VPCI_708/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692059.1 Candida auris isolate VPCI_677/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692058.1 Candida auris isolate VPCI_676/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692057.1 Candida auris isolate VPCI_674/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692056.1 Candida auris isolate VPCI_673/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692055.1 Candida auris isolate VPCI_672/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692054.1 Candida auris isolate VPCI_670/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692053.1 Candida auris isolate VPCI_669/P/12 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692052.1 Candida auris isolate VPCI_712/P/12 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# KC692051.1 Candida auris isolate VPCI_671/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692050.1 Candida auris isolate VPCI_692/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692049.1 Candida auris isolate VPCI_683/P/12 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692048.1 Candida auris isolate VPCI_711/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692047.1 Candida auris isolate VPCI_709/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692046.1 Candida auris isolate VPCI_708/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# KC692045.1 Candida auris isolate VPCI_677/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692044.1 Candida auris isolate VPCI_676/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692043.1 Candida auris isolate VPCI_674/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692042.1 Candida auris isolate VPCI_673/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692041.1 Candida auris isolate VPCI_672/P/12 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# []
#
#
# KC692040.1 Candida auris isolate VPCI_670/P/12 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# KC692039.1 Candida auris isolate VPCI_669/P/12 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# JX459746.1 Candida auris strain KCTC17809 DNA-dependent RNA polymerase II second largest subunit (RPB2) gene, partial cds
# []
#
#
# JX459745.1 Candida auris strain KCTC17810 DNA-dependent RNA polymerase II second largest subunit (RPB2) gene, partial cds
# []
#
#
# JX459780.1 Candida auris strain KCTC17809 26S ribosomal RNA gene, partial sequence
# []
# JX459779.1 Candida auris strain KCTC17810 26S ribosomal RNA gene, partial sequence
# []
#
#
# JX459679.1 Candida auris strain KCTC17810 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# []
#
#
# HE797775.1 Candida auris partial 28S rRNA gene, strain CH2
# []
#
#
# HE797774.1 Candida auris partial 28S rRNA gene, strain CH1
# []
#
#
# HE797773.1 Candida auris genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2, 28S rRNA gene, strain CH2
# []
#
#
# HE797772.1 Candida auris genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2, 28S rRNA gene, strain CH1
# []
#
#
# JQ219332.1 Candida auris strain TA296 26S ribosomal RNA gene, partial sequence
# []
#
#
# JQ219331.1 Candida auris strain BJ113 26S ribosomal RNA gene, partial sequence
# []
#
#
# AB375773.1 Candida auris gene for 26S ribosomal RNA, partial sequence
# []
#
#
# AB375772.1 Candida auris genes for 18S rRNA, ITS1, 5.8S rRNA, ITS2, 28S rRNA, partial and complete sequence
# []

# %%
# Compute the compression ratio = initial_size / current_size of DB

# sanity checking the calculations around compression ratio
len_of_key_pair.sort()
#print(sum(len_of_key_pair))
#print(len(result_df.index) - sum(len_of_key_pair))
#len_of_key_pair[-10:]

# compression ratio
print("initial count of accession: " + str(len(result_df.index)))
print("final count after clustering: " + str(len(result_dict.keys())))
print("compression ratio: " + str(len(result_df.index) / len(result_dict.keys())))
# Out:
# initial count of accession: 8585
# final count after clustering: 3796
# compression ratio: 2.26159114857745

# %% [markdown]
# ### Take the clustered data and generate a new .fasta file of accessions

# %%
records = list(SeqIO.parse(this_dump + ".fasta", "fasta"))
new_dump_fasta = this_dump + '.new.fasta'
with open(new_dump_fasta, 'w') as f: 
    for r in records:
        seqid = r.description
        if seqid in result_dict.keys():
            f.write('>' + seqid + '\n' + str(r.seq) + '\n')
f.close()
