# %%
from Bio import SeqIO
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %matplotlib inline

# %%
def greedy_partition(df, threshold):

    ignore_index = []
    tally_dict = {}

    debug=False

    for row_id in df.index:

        if debug:
            print(row_id)
            print(ignore_index)

        # if we've already assigned this index as a child, don't need to consider it's row
        if not(row_id in ignore_index):

            # get the full dataframe row for this sample
            this_row_init = df.loc[row_id]  

            # remove columns that are already children of other nodes
            this_row = this_row_init.drop(labels = ignore_index)  
            #print(this_row)
            if debug:
                print(this_row_init.shape)
                print(this_row.shape)

            # children of this node are those with values greather than the threshold...
            children = list(this_row[this_row > threshold].index)
            children_filtered = [i for i in children if i != row_id ] #...not inlucding the node name itself

            if debug:
                print("len of children_filtered: " + str(len(children_filtered)) + '\n\n')

            # add the node + children to the dictionary, 
            # then add node + children to the set to ignore in future iterations
            tally_dict[row_id] = children_filtered
            ignore_index += children_filtered
            ignore_index += [row_id]

    return(tally_dict)

# %%
# Iteratively run sourmash at varying *scaled* parameters...
# and plot the sourmash distances as a function of the known percent identity

this_dump = "chkv_txid37124_dump"

#%%capture
K = 31
ST = 1000
    
start = time.time()

! mkdir {this_dump}
! rm cmp*;
! rm *sig;
! sourmash sketch dna -p k={K},scaled={ST} --singleton {this_dump}.fasta;
! sourmash compare *.sig --containment -o {this_dump}/cmp.dist;
! sourmash compare *.sig --containment -o {this_dump}/cmp.dist --csv {this_dump}/cmp.csv;

end = time.time()
elapsed = end - start
# Out:
# mkdir: chkv_txid37124_dump: File exists
# zsh:1: no matches found: cmp*
# zsh:1: no matches found: *sig
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# computing signatures for files: chkv_txid37124_dump.fasta
# Computing a total of 1 signature(s) for each input.
# calculated 6947 signatures for 6947 sequences in chkv_txid37124_dump.fasta
# saved 6947 signature(s) to 'chkv_txid37124_dump.fasta.sig'. Note: signature license is CC0.
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 6947 signatures total.
#
# min similarity in matrix: 0.000
# saving labels to: chkv_txid37124_dump/cmp.dist.labels.txt
# saving comparison matrix to: chkv_txid37124_dump/cmp.dist
# WARNING: size estimation for at least one of these sketches may be inaccurate. ANI values will be set to 1 for these comparisons.
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 6947 signatures total.
#
# min similarity in matrix: 0.000
# saving labels to: chkv_txid37124_dump/cmp.dist.labels.txt
# saving comparison matrix to: chkv_txid37124_dump/cmp.dist
# WARNING: size estimation for at least one of these sketches may be inaccurate. ANI values will be set to 1 for these comparisons.

# %%
result_df = pd.read_csv(this_dump + "/cmp.csv")
result_df.index = result_df.columns
result_df.shape

result_dict = greedy_partition(result_df, .6)

# %%
for key in result_dict:
    print(key)
    print(result_dict[key])
    print('\n')
# Out:
# gi|2440741213|gb|ON453887.1| Chikungunya virus isolate SGEHIKJ71albY08 envelope 1 gene, partial cds
# []
#
#
# gi|2440740930|gb|ON406435.1| Chikungunya virus isolate TM198 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740928|gb|ON406434.1| Chikungunya virus isolate TM033 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740926|gb|ON406433.1| Chikungunya virus isolate TM026 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740924|gb|ON406432.1| Chikungunya virus isolate TM025 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740922|gb|ON406431.1| Chikungunya virus isolate TM015 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740920|gb|ON406430.1| Chikungunya virus isolate TM008 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740918|gb|ON406429.1| Chikungunya virus isolate TM007 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740916|gb|ON406428.1| Chikungunya virus isolate TM004 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740914|gb|ON406427.1| Chikungunya virus isolate TM248 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740912|gb|ON406426.1| Chikungunya virus isolate TM009 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740910|gb|ON406425.1| Chikungunya virus isolate TM155 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740908|gb|ON406424.1| Chikungunya virus isolate TM217 structural polyprotein gene, partial cds
# []
#
#
# gi|2440740906|gb|ON406423.1| Chikungunya virus isolate TM073 structural polyprotein gene, partial cds
# []
#
#
# gi|2315911188|gb|ON142089.1| UNVERIFIED: Chikungunya virus isolate VolunteerID50_Arbobios_DO_Chronic sequence
# ['gi|2315911187|gb|ON142088.1| UNVERIFIED: Chikungunya virus isolate VolunteerID54_Arbobios_DO_Chronic sequence', 'gi|2315911186|gb|ON142087.1| UNVERIFIED: Chikungunya virus isolate VolunteerID142_Arbobios_DO_Control sequence', 'gi|2315911185|gb|ON142086.1| UNVERIFIED: Chikungunya virus isolate VolunteerID139_Arbobios_DO_Control sequence', 'gi|2315911184|gb|ON142085.1| UNVERIFIED: Chikungunya virus isolate VolunteerID71_Arbobios_DO_Control sequence', 'gi|2315911183|gb|ON142084.1| UNVERIFIED: Chikungunya virus isolate VolunteerID154_Arbobios_DO_Control sequence', 'gi|2315911182|gb|ON142083.1| UNVERIFIED: Chikungunya virus isolate VolunteerID138_Arbobios_DO_Control sequence', 'gi|2315911181|gb|ON142082.1| UNVERIFIED: Chikungunya virus isolate VolunteerID74_Arbobios_DO_Chronic sequence', 'gi|2315911180|gb|ON142081.1| UNVERIFIED: Chikungunya virus isolate VolunteerID65_Arbobios_DO_Chronic sequence', 'gi|2315911179|gb|ON142080.1| UNVERIFIED: Chikungunya virus isolate VolunteerID70_Arbobios_DO_Chronic sequence', 'gi|2315911178|gb|ON142079.1| UNVERIFIED: Chikungunya virus isolate VolunteerID9_Arbobios_DO_Chronic sequence', 'gi|2315911177|gb|ON142078.1| UNVERIFIED: Chikungunya virus isolate VolunteerID33_Arbobios_DO_Chronic sequence', 'gi|2315911176|gb|ON142077.1| UNVERIFIED: Chikungunya virus isolate VolunteerID13_Arbobios_D21_Chronic sequence', 'gi|2315911175|gb|ON142076.1| UNVERIFIED: Chikungunya virus isolate VolunteerID16_Arbobios_D0_Chronic sequence', 'gi|2315911174|gb|ON142075.1| UNVERIFIED: Chikungunya virus isolate VolunteerID72_Arbobios_D0_Control sequence', 'gi|2315911173|gb|ON142074.1| UNVERIFIED: Chikungunya virus isolate VolunteerID12_Arbobios_D0_Chronic sequence', 'gi|2315911172|gb|ON142073.1| UNVERIFIED: Chikungunya virus isolate VolunteerID18_Ar
Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924778|gb|MZ726834.1| Chikungunya virus isolate 41_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924776|gb|MZ726833.1| Chikungunya virus isolate 40_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924774|gb|MZ726832.1| Chikungunya virus isolate 24__Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924772|gb|MZ726831.1| Chikungunya virus isolate 69_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924770|gb|MZ726830.1| Chikungunya virus isolate 5_Pak_2016 capsid gene, partial cds
# []
#
#
# gi|2318924768|gb|MZ726829.1| Chikungunya virus isolate 546_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924766|gb|MZ726828.1| Chikungunya virus isolate 355_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924764|gb|MZ726827.1| Chikungunya virus isolate 401_Pak_2017 capsid gene, partial cds
# []
#
#
# gi|2318924762|gb|MZ726826.1| Chikungunya virus isolate 78_Pak_2018 capsid gene, partial cds
# []
#
#
# gi|2318924760|gb|MZ726825.1| Chikungunya virus isolate 30_Pak_2016 capsid gene, partial cds
# []
#
#
# gi|2318924758|gb|MZ726824.1| Chikungunya virus isolate 15_Pak_2016 capsid gene, partial cds
# []
#
#
# gi|2318924736|gb|MZ726813.1| Chikungunya virus isolate 71_Pak_2016 Nsp1 gene, partial cds
# []
#
#
# gi|2318924734|gb|MZ726812.1| Chikungunya virus isolate 30_Pak_2016 Nsp1 gene, partial cds
# []
#
#
# gi|2318924732|gb|MZ726811.1| Chikungunya virus isolate 166_Pak_2017 Nsp1 gene, partial cds
# []
#
#
# gi|2318924730|gb|MZ726810.1| Chikungunya virus isolate 78_Pak_2017 Nsp1 gene, partial cds
# []
#
#
# gi|2318924728|gb|MZ726809.1| Chikungunya virus isolate 22_Pak_2017 Nsp1 gene, partial cds
# []
#
#
# gi|2318924726|gb|MZ726808.1| Chikungunya virus isolate 41_Pak_2017 Nsp1 gene, partial cds
# []
#
#
# gi|2318924724|gb|MZ726807.1| Chikungunya virus isolate 10_Pak_2018 Nsp1 gene, partial cds
# []
#
#
# gi|2318924722|gb|MZ726806.1| Chikungunya virus isolate 26_Pak_2018 Nsp1 gene, partial cds
# []
#
#
# gi|2318924720|gb|MZ726805.1| Chikungunya virus isolate 8_Pak_2016 Nsp1 gene, partial cds
# []
#
#
# gi|2318924718|gb|MZ726804.1| Chikungunya virus isolate 5_Pak_2016 Nsp1 gene, partial cds
# []
#
#
# gi|2315909757|gb|MZ701738.1| Chikungunya virus isolate 540_Pak_2017 Nsp2 gene, partial cds
# []
#
#
# gi|2315909755|gb|MZ701737.1| Chikungunya virus isolate 71_Pak_2016 Nsp2 gene, partial cds
# ['gi|2315909753|gb|MZ701736.1| Chikungunya virus isolate 30-Pak-_2016 Nsp2 gene, partial cds', 'gi|2315909751|gb|MZ701735.1| Chikungunya virus isolate 166-Pak_2017 Nsp2 gene, partial cds', 'gi|2315909749|gb|MZ701734.1| Chikungunya virus isolate 78_Pak_2017 Nsp2 gene, partial cds', 'gi|2315909747|gb|MZ701733.1| Chikungunya virus isolate 15_Pak_2016 Nsp2 gene, partial cds', 'gi|2315909745|gb|MZ701732.1| Chikungunya virus isolate 24_Pak_2017 Nsp2 gene, partial cds', 'gi|2315909743|gb|MZ701731.1| Chikungunya virus isolate 41_Pak_2017 Nsp2 gene, partial cds', 'gi|2315909741|gb|MZ701730.1| Chikungunya virus isolate 10_Pak_2018 Nsp2 gene, partial cds', 'gi|2315909739|gb|MZ701729.1| Chikungunya virus isolate 26_Pak_2018 Nsp2 gene, partial cds', 'gi|2315909737|gb|MZ701728.1| Chikungunya virus isolate 8_Pak_2016 Nsp2 gene, partial cds', 'gi|2315909735|gb|MZ701727.1| Chikungunya virus isolate 5_Pak_2016 Nsp2 gene, partial cds']
#
#
# gi|2315909733|gb|MZ701726.1| Chikungunya virus isolate 540_Pak_2017 Nsp3 gene, partial cds
# ['gi|2315909731|gb|MZ701725.1| Chikungunya virus isolate 30_Pak_2017 Nsp3 gene, partial cds', 'gi|2315909729|gb|MZ701724.1| Chikungunya virus isolate 166_Pak_2017 Nsp3 gene, partial cds', 'gi|2315909727|gb|MZ701723.1| Chikungunya virus isolate 78_Pak_2017 Nsp3 gene, partial cds', 'gi|2315909725|gb|MZ701722.1| Chikungunya virus isolate 15_Pak_2017 Nsp3 gene, partial cds', 'gi|2315909723|gb|MZ701721.1| Chikungunya virus isolate 40_Pak_2017 Nsp3 gene, partial cds', 'gi|2315909721|gb|MZ701720.1| Chikungunya virus isolate 10_Pak_2018 Nsp3 gene, partial cds', 'gi|2315909719|gb|MZ701719.1| Chikungunya virus isolate 26-Pak_2018 Nsp3 gene, partial cds', 'gi|2315909717|gb|MZ701718.1| Chikungunya virus isolate 8_Pak_2016 Nsp3 gene, partial cds', 'gi|2315909715|gb|MZ701717.1| Chikungunya virus isolate 5_Pak_2016 Nsp3 gene, partial cds']
#
#
# gi|2315449154|gb|MZ673050.1| Chikungunya virus isolate Fiji-2016-116147357 E protein gene, partial cds
# []
#
#
# gi|2315449152|gb|MZ673049.1| Chikungunya virus isolate Fiji-2016-116147354 E protein gene, partial cds
# []
#
#
# gi|2315449150|gb|MZ673048.1| Chikungunya virus isolate Fiji-2016-116147240 E protein gene, partial cds
# []
#
#
# gi|2315449148|gb|MZ673047.1| Chikungunya virus isolate NewCaledonia-2016-116025197 E protein gene, partial cds
# []
#
#
# gi|2315449146|gb|MZ673046.1| Chikungunya virus isolate NewCaledonia-2016-116025193 E protein gene, partial cds
# []
#
#
# gi|2315449144|gb|MZ673045.1| Chikungunya virus isolate NewCaledonia-2014-114343328-8008 E protein gene, partial cds
# []
#
#
# gi|2315449142|gb|MZ673044.1| Chikungunya virus isolate NewCaledonia-2014-114304281-7576 E protein gene, partial cds
# []
#
#
# gi|2315449140|gb|MZ673043.1| Chikungunya virus isolate NewCaledonia-2013-280213-5988 E protein gene, partial cds
# []
#
#
# gi|2315449138|gb|MZ673042.1| Chikungunya virus isolate NewCaledonia-2013-270413-14936 E protein gene, partial cds
# []
#
#
# gi|2315449136|gb|MZ673041.1| Chikungunya virus isolate NewCaledonia-2013-180113-1167 E protein gene, partial cds
# []
#
#
# gi|2315449134|gb|MZ673040.1| Chikungunya virus isolate NewCaledonia-2013-060513-16786 E protein gene, partial cds
# []
#
#
# gi|2315449132|gb|MZ673039.1| Chikungunya virus isolate NewCaledonia-2013-030613-19451 E protein gene, partial cds
# []
#
#
# gi|2315449130|gb|MZ673038.1| Chikungunya virus isolate NewCaledonia-2013-020513-16440 E protein gene, partial cds
# []
#
#
# gi|2310822351|gb|OP265748.1| Chikungunya virus isolate BS1_Sarawak_2009 E1 protein gene, partial cds
# []
#
#
# gi|2291344054|gb|MW888465.1| UNVERIFIED: Chikungunya virus strain CHIKV-KOLKATA(WB)-2017 genomic sequence
# []
#
#
# gi|2289591942|dbj|LC707379.1| Chikungunya virus SYMAV-H0915 E1 gene for envelope protein 1, partial cds
# ['gi|171918912|gb|EU403052.1| Chikungunya virus structural polyprotein gene, partial cds', 'gi|169249251|gb|EU287998.1| Chikungunya virus isolate ALP-9 envelope glycoprotein 1 gene, partial cds', 'gi|157092545|gb|EF613344.1| Chikungunya virus isolate 8849 envelope E1 gene, partial cds', "gi|124295281|gb|EF051584.1| Chikungunya virus isolate Chik Cam 7079 structural protein E1 gene, partial cds; and 3' UTR", 'gi|746645268|gb|KJ508821.1| Chikungunya virus isolate 13V-2980_CHIK E1 protein gene, partial cds', 'gi|391226677|gb|JX080288.1| Chikungunya virus isolate GA3-18 structural polyprotein gene, partial cds', 'gi|391226675|gb|JX080287.1| Chikungunya virus isolate GA12-1 structural polyprotein gene, partial cds', 'gi|391226673|gb|JX080286.1| Chikungunya virus isolate GA_CHIKV structural polyprotein gene, partial cds']
#
#
# gi|2273855673|gb|OL343617.1| Chikungunya virus isolate Amapa_695_Brazil_2016 nonstructural polyprotein and structural polyprotein genes, partial cds
# ['gi|2273855670|gb|OL343616.1| Chikungunya virus isolate Amapa_575_Brazil_2015 nonstructural polyprotein gene, complete cds; and structural polyprotein gene, partial cds', 'gi|2273855667|gb|OL343615.1| Chikungunya virus isolate Amapa_548_Brazil_2015 nonstructural polyprotein and structural polyprotein genes, complete cds', 'gi|2273855661|gb|OL343613.1| Chikungunya virus isolate Amapa_351_Brazil_2015 nonstructural polyprotein and structural polyprotein genes, partial cds', 'gi|2273855658|gb|OL343612.1| Chikungunya virus isolate Amapa_139_Brazil_2014 nonstructural polyprotein and structural polyprotein genes, complete cds', 'gi|2273855655|gb|OL343611.1| Chikungunya virus isolate Amapa_181_Brazil_2014 nonstructural polyprotein and structural polyprotein genes, partial cds', 'gi|2273855649|gb|OL343609.1| Chikungunya virus isolate Amapa_564_Brazil_2015 nonstructural polyprotein and structural polyprotein genes, partial cds', 'gi|2239584644|gb|OM799590.1| Chikungunya virus isolate CHIKV-China/W2016C-3 capsid protein (C) gene, partial cds', 'gi|2239584642|gb|OM799589.1| Chikungunya virus isolate CHIKV-China/W2016C-2 capsid protein (C) gene, partial cds', 'gi|2239584638|gb|OM799587.1| Chikungunya virus isolate CHIKV-China/B2016C-3 capsid protein (C) gene, partial cds', 'gi|2239584636|gb|OM799586.1| Chikungunya virus isolate CHIKV-China/B2016C-2 capsid protein (C) gene, partial cds', 'gi|2239584632|gb|OM799584.1| Chikungunya virus isolate CHIKV-China/CT2016C-5 capsid protein (C) gene, partial cds', 'gi|2239584630|gb|OM799583.1| Chikungunya virus isolate CHIKV-China/CT2016C-3 capsid protein (C) gene, partial cds', 
2015 nonstructural polyprotein gene, partial cds', 'gi|1754218636|gb|MK632330.1| Chikungunya virus strain InDRE 344 Oaxaca 2015 nonstructural polyprotein gene, partial cds', 'gi|1754218634|gb|MK632329.1| Chikungunya virus strain InDRE 139 Oaxaca 2014 nonstructural polyprotein gene, partial cds', 'gi|1754218632|gb|MK632328.1| Chikungunya virus strain InDRE 133 Oaxaca 2014 nonstructural polyprotein gene, partial cds', 'gi|1754218630|gb|MK632327.1| Chikungunya virus strain InDRE 104 Guerrero 2015 nonstructural polyprotein gene, partial cds', 'gi|1754218628|gb|MK632326.1| Chikungunya virus strain InDRE 103 Guerrero 2015 nonstructural polyprotein gene, partial cds', 'gi|1754218626|gb|MK632325.1| Chikungunya virus strain InDRE 99 Guerrero 2015 nonstructural polyprotein gene, partial cds', 'gi|1754218624|gb|MK632324.1| Chikungunya virus strain InDRE 64 Veracruz 2015 nonstructural polyprotein gene, partial cds', 'gi|2239727540|gb|OK316996.1| Chikungunya virus clone 625B3h, complete genome', 'gi|2239727537|gb|OK316995.1| Chikungunya virus clone 625D6h, complete genome', 'gi|2239727534|gb|OK316994.1| Chikungunya virus clone 631A1h, complete genome', 'gi|2239727531|gb|OK316993.1| Chikungunya virus clone 631C6h, complete genome', 'gi|2239727528|gb|OK316992.1| Chikungunya virus clone 1151D4f, complete genome', 'gi|2239727522|gb|OK316990.1| Chikungunya virus clone 1156D2a, complete genome', 'gi|2239727519|gb|OK316989.1| Chikungunya virus clone 1156E4e, complete genome', 'gi|2239584607|gb|OM799572.1| Chikungunya virus isolate CHIKV-China/CT2016E1-3 envelope protein 1 (E1) gene, partial cds', 'gi|2239584604|gb|OM799571.1| Chikungunya virus isolate CHIKV-China/CT2016E1-2 envelope protein 1 (E1) gene, partial cds', 'gi|2239584601|gb|OM799570.1| Chikungunya virus isolate CHIKV-China/CT2016E1-1 envelope protein 1 (E1) gene, partial cds', 'gi|2191949986|gb|MZ292728.1| Chikungunya virus isolate 2014-CV001 (ex French Polynesia) structural polyprotein gene, partial cds', 'gi|2177581535|gb|OK655884.1| Chikungunya virus isolate CHIKV/IDN_Jambi_101/2016, partial genome', 'gi|2177581532|gb|OK655883.1| Chikungunya virus isolate CHIKV/IDN_Jambi_112/2016, partial genome', 'gi|2177581529|gb|OK655882.1| Chikungunya virus isolate CHIKV/IDN_Jambi_129/2016, partial genome', 'gi|2046300900|gb|MW656171.1| Chikungunya virus isolate Gi_COL7624, complete genome', 'gi|1934642748|gb|MT591107.1| Chikungunya virus isolate AMB-041 nonstructural polyprotein gene, partial cds; and structural polyprotein gene, c ...
#
#
# gi|2271163419|gb|ON207128.1| Chikungunya virus isolate JMBSCHIK.002 envelope E1 protein gene, partial cds
# []
#
#
# gi|2271163417|gb|ON207127.1| Chikungunya virus isolate JMBSCHIK.001 envelope E1 protein gene, partial cds
# []
#
#
# gi|2271163415|gb|ON207126.1| Chikungunya virus isolate JMBC21.008 envelope E1 protein gene, partial cds
# []
#
#
# gi|2250411963|gb|MW591597.1| Chikungunya virus isolate 645_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411961|gb|MW591596.1| Chikungunya virus isolate 75_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411959|gb|MW591595.1| Chikungunya virus isolate 53_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411957|gb|MW591594.1| Chikungunya virus isolate 41_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411955|gb|MW591593.1| Chikungunya virus isolate 40_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411953|gb|MW591592.1| Chikungunya virus isolate 8_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411951|gb|MW591591.1| Chikungunya virus isolate 24_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411949|gb|MW591590.1| Chikungunya virus isolate 26_PAKISTAN_2017 E1 gene, partial cds
# []
#
#
# gi|2250411947|gb|MW591589.1| Chikungunya virus isolate 52_PAKISTAN_2016 E1 gene, partial cds
# []
#
#
# gi|2250411945|gb|MW591588.1| Chikungunya virus isolate 13_PAKISTAN_2016 E1 gene, partial cds
# []
#
#
# gi|2250411943|gb|MW591587.1| Chikungunya virus isolate 51_PAKISTAN_2016 E1 gene, partial cds
# []
#
#
# gi|2242464103|dbj|OF338499.1| KR 1020210116712-A/7: MALARIA VACCINE
# ['gi|2242464101|dbj|OF338497.1| KR 1020210116712-A/5: MALARIA VACCINE', 'gi|1812619150|gb|MN158171.1| Chikungunya virus isolate KNIH/2009/77 structural polyprotein mRNA, complete cds', 'gi|1746462114|dbj|LY575875.1| KR 1020180004403-A/268: ANTIBODY-MEDIATED NEUTRALIZATION OF CHIKUNGUNYA VIRUS', 'gi|1746462113|dbj|LY575874.1| KR 1020180004403-A/267: ANTIBODY-MEDIATED NEUTRALIZATION OF CHIKUNGUNYA VIRUS', 'gi|1720077920|gb|MN102099.1| Chikungunya virus isolate CHIK/P3/MIV/2014 structural polyprotein gene, partial cds', 'gi|1525604673|dbj|MA407074.1| JP 2018520334-A/61: ANTIBODY-MEDIATED NEUTRALIZATION OF CHIKUNGUNYA VIRUS', 'gi|1525604672|dbj|MA407073.1| JP 2018520334-A/60: ANTIBODY-MEDIATED NEUTRALIZATION OF CHIKUNGUNYA VIRUS', 'gi|1502961438|gb|MH347345.1| Chikungunya virus isolate 2017-MH_Pune1732672 E2 protein gene, partial cds', 'gi|1502961436|gb|MH347344.1| Chikungunya virus isolate 2015-KA_Blore5813 E2 protein gene, partial cds', 'gi|1502961434|gb|MH347343.1| Chikungunya virus isolate 2015-KA_Blore5181 E2 protein gene, partial cds', 'gi|1502961428|gb|MH347340.1| Chikungunya virus isolate 2015-KA_Blore9161 E2 protein gene, partial cds', 'gi|1390435774|gb|MF346359.1| Chikungunya virus isolate IND-2015-KA_Blore5310 envelope protein E2 gene, partial cds', 'gi|1384681149|emb|LP809668.1| Sequence 268 from Patent EP3283101', 'gi|1384681148|emb|LP809667.1| Sequence 267 from Patent EP3283101', 'gi|578897399|gb|KF818475.1| Chikungunya virus isolate IND-11-WBST4 structural protein gene, complete cds', 'gi|578897397|gb|KF818474.1| Chikungunya virus isolate IND-12-WBST
#
#
# gi|2239584678|gb|OM416163.1| Chikungunya virus strain CHIKV-China/P2020E1-1 envelope 1 protein gene, partial cds
# ['gi|2239584612|gb|OM799574.1| Chikungunya virus isolate CHIKV-China/W2016E1-1 envelope protein 1 (E1) gene, partial cds', 'gi|2205350761|gb|MZ494489.1| Chikungunya virus isolate CHIKV-China/YN2018E1-1 envelope protein 1 (E1) gene, partial cds']
#
#
# gi|2239584676|gb|OM416162.1| Chikungunya virus strain CHIKV-China/P2020E1-2 envelope 1 protein gene, partial cds
# []
#
#
# gi|2239584674|gb|OM416161.1| Chikungunya virus strain CHIKV-China/P2020E1-3 envelope 1 protein gene, partial cds
# ['gi|2239584616|gb|OM799576.1| Chikungunya virus isolate CHIKV-China/W2016E1-3 envelope protein 1 (E1) gene, partial cds']
#
#
# gi|2239584672|gb|OM416160.1| Chikungunya virus strain CHIKV-China/P2020E1-4 envelope 1 protein gene, partial cds
# []
#
#
# gi|2239584670|gb|OM416159.1| Chikungunya virus strain CHIKV-China/P2020NS1-1 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|2239584668|gb|OM416158.1| Chikungunya virus strain CHIKV-China/P2020NS1-2 nonstructural protein 1 gene, partial cds
# ['gi|2239584620|gb|OM799578.1| Chikungunya virus isolate CHIKV-China/B2016NS1-2 nonstructural protein 1 (NS1) gene, partial cds']
#
#
# gi|2239584666|gb|OM416157.1| Chikungunya virus strain CHIKV-China/P2020NS1-3 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|2239584640|gb|OM799588.1| Chikungunya virus isolate CHIKV-China/W2016C-1 capsid protein (C) gene, partial cds
# []
#
#
# gi|2239584634|gb|OM799585.1| Chikungunya virus isolate CHIKV-China/B2016C-1 capsid protein (C) gene, partial cds
# []
#
#
# gi|2239584626|gb|OM799581.1| Chikungunya virus isolate CHIKV-China/CT2016C-1 capsid protein (C) gene, partial cds
# []
#
#
# gi|2239584618|gb|OM799577.1| Chikungunya virus isolate CHIKV-China/B2016NS1-1 nonstructural protein 1 (NS1) gene, partial cds
# []
#
#
# gi|2239584614|gb|OM799575.1| Chikungunya virus isolate CHIKV-China/W2016E1-2 envelope protein 1 (E1) gene, partial cds
# []
#
#
# gi|2239584609|gb|OM799573.1| Chikungunya virus isolate CHIKV-China/CT2016E1-4 envelope protein 1 (E1) gene, partial cds
# []
#
#
# gi|1399601166|gb|MG262525.1| Chikungunya virus isolate INCA19.RJ.280416 E1 protein gene, partial cds
# []
#
#
# gi|1399601164|gb|MG262524.1| Chikungunya virus isolate INCA18.RJ.280416 E1 protein gene, partial cds
# []
#
#
# gi|1399601162|gb|MG262523.1| Chikungunya virus isolate INCA17.RJ.040416 E1 protein gene, partial cds
# []
#
#
# gi|1399601160|gb|MG262522.1| Chikungunya virus isolate INCA16.RJ.310316 E1 protein gene, partial cds
# []
#
#
# gi|1399601158|gb|MG262521.1| Chikungunya virus isolate INCA15.RJ.290316 E1 protein gene, partial cds
# []
#
#
# gi|1399601156|gb|MG262520.1| Chikungunya virus isolate INCA14.RJ.110516 E1 protein gene, partial cds
# []
#
#
# gi|1399601154|gb|MG262519.1| Chikungunya virus isolate INCA13.RJ.040516 E1 protein gene, partial cds
# []
#
#
# gi|1399601152|gb|MG262518.1| Chikungunya virus isolate INCA12.RJ.260416 E1 protein gene, partial cds
# []
#
#
# gi|1399601150|gb|MG262517.1| Chikungunya virus isolate INCA11.RJ.260416 E1 protein gene, partial cds
# []
#
#
# gi|1399601148|gb|MG262516.1| Chikungunya virus isolate INCA10.RJ.260416 E1 protein gene, partial cds
# []
#
#
# gi|1399601146|gb|MG262515.1| Chikungunya virus isolate INCA9.RJ.220416 E1 protein gene, partial cds
# []
#
#
# gi|1399601144|gb|MG262514.1| Chikungunya virus isolate INCA8.RJ.220416 E1 protein gene, partial cds
# []
#
#
# gi|1399601142|gb|MG262513.1| Chikungunya virus isolate INCA7.RJ.180416 E1 protein gene, partial cds
# []
#
#
# gi|1399601140|gb|MG262512.1| Chikungunya virus isolate INCA6.RJ.140416 E1 protein gene, partial cds
# []
#
#
# gi|1399601138|gb|MG262511.1| Chikungunya virus isolate INCA5.RJ.110416 E1 protein gene, partial cds
# []
#
#
# gi|1399601136|gb|MG262510.1| Chikungunya virus isolate INCA4.RJ.060516 E1 protein gene, partial cds
# []
#
#
# gi|1399601134|gb|MG262509.1| Chikungunya virus isolate INCA3.RJ.290416 E1 protein gene, partial cds
# []
#
#
# gi|1399601132|gb|MG262508.1| Chikungunya virus isolate INCA2.RJ.250416 E1 protein gene, partial cds
# []
#
#
# gi|1399601130|gb|MG262507.1| Chikungunya virus isolate INCA1.RJ.010416 E1 protein gene, partial cds
# []
#
#
# gi|2216793899|gb|MW281311.1| Chikungunya virus strain 2017/FR/45625-26, complete genome
# ['gi|1992350185|gb|MT666073.1| Chikungunya virus strain CAM/2018/Mfuo, complete genome', 'gi|1992350182|gb|MT666072.1| Chikungunya virus strain CAM/2016/Yaounde, complete genome', 'gi|1992350179|gb|MT666071.1| Chikungunya virus strain CAM/2018/Yaounde, complete genome', 'gi|1229873089|gb|KP003813.2| Chikungunya virus strain BRAZZA_MRS1, partial genome', 'gi|745698484|gb|KP003812.1| Chikungunya virus strain GABOPY1, complete genome']
#
#
# gi|2205350777|gb|MZ494497.1| Chikungunya virus isolate CHIKV-China/YN2018NS3-5 non-structural protein 3 (NS3) gene, partial cds
# ['gi|2205350769|gb|MZ494493.1| Chikungunya virus isolate CHIKV-China/YN2018NS3-1 non-structural protein 3 (NS3) gene, partial cds']
#
#
# gi|2205350775|gb|MZ494496.1| Chikungunya virus isolate CHIKV-China/YN2018NS3-4 non-structural protein 3 (NS3) gene, partial cds
# []
#
#
# gi|2205350773|gb|MZ494495.1| Chikungunya virus isolate CHIKV-China/YN2018NS3-3 non-structural protein 3 (NS3) gene, partial cds
# []
#
#
# gi|2205350771|gb|MZ494494.1| Chikungunya virus isolate CHIKV-China/YN2018NS3-2 non-structural protein 3 (NS3) gene, partial cds
# []
#
#
# gi|2205350767|gb|MZ494492.1| Chikungunya virus isolate CHIKV-China/YN2018E1-4 envelope protein 1 (E1) gene, partial cds
# []
#
#
# gi|2205350765|gb|MZ494491.1| Chikungunya virus isolate CHIKV-China/YN2018E1-3 envelope protein 1 (E1) gene, partial cds
# ['gi|375269288|gb|JN711135.1| Chikungunya virus isolate 18/RMRC/Kendrapara envelope glycoprotein 1 gene, partial cds', 'gi|375269286|gb|JN711134.1| Chikungunya virus isolate 17/RMRC/Kendrapara envelope glycoprotein 1 gene, partial cds', 'gi|375269284|gb|JN711133.1| Chikungunya virus isolate 16/RMRC/Kendrapara envelope glycoprotein 1 gene, partial cds', 'gi|375269282|gb|JN711132.1| Chikungunya virus isolate 15/RMRC/Jagatsinghpur envelope glycoprotein 1 gene, partial cds', 'gi|375269280|gb|JN711131.1| Chikungunya virus isolate 14/RMRC/Jagatsinghpur envelope glycoprotein 1 gene, partial cds', 'gi|375269278|gb|JN711130.1| Chikungunya virus isolate 13/RMRC/Jagatsinghpur envelope glycoprotein 1 gene, partial cds', 'gi|375269276|gb|JN711129.1| Chikungunya virus isolate 12/RMRC/Puri envelope glycoprotein 1 gene, partial cds', 'gi|375269274|gb|JN711128.1| Chikungunya virus isolate 11/RMRC/Puri envelope glycoprotein 1 gene, partial cds', 'gi|375269272|gb|JN711127.1| Chikungunya virus isolate 10/RMRC/Puri envelope glycoprotein 1 gene, partial cds']
#
#
# gi|2205350763|gb|MZ494490.1| Chikungunya virus isolate CHIKV-China/YN2018E1-2 envelope protein 1 (E1) gene, partial cds
# []
#
#
# gi|2191949988|gb|MZ292729.1| Chikungunya virus isolate 2019-9293 (ex Indonesia) structural polyprotein gene, partial cds
# []
#
#
# gi|2178350980|gb|MT298202.1| Chikungunya virus isolate RDN14 envelope glycoprotein 1 gene, partial cds
# []
#
#
# gi|2178350978|gb|MT298201.1| Chikungunya virus isolate RDN13 envelope glycoprotein 1 gene, partial cds
# []
#
#
# gi|2178350976|gb|MT298200.1| Chikungunya virus isolate RDN12 envelope glycoprotein 1 gene, partial cds
# []
#
#
# gi|2178350974|gb|MT298199.1| Chikungunya virus isolate RDN11 envelope glycoprotein 1 gene, partial cds
# []
#
#
# gi|2178350972|gb|MT298198.1| Chikungunya virus isolate RDN10 envelope glycoprotein 1 gene, partial cds
# []
#
#
# gi|2169123535|gb|OL692741.1| Chikungunya virus isolate 20V-14211_CHAD2020 surface glycoprotein gene, partial cds
# ['gi|2169123533|gb|OL692740.1| Chikungunya virus isolate 20V-14210_CHAD2020 surface glycoprotein gene, partial cds', 'gi|1973536569|gb|MW271627.1| Chikungunya virus isolate BKK15701 envelope glycoprotein E1 gene, partial cds', 'gi|1973536557|gb|MW271621.1| Chikungunya virus isolate BKK15529 envelope glycoprotein E1 gene, partial cds', 'gi|1386678505|gb|MG697276.1| Chikungunya virus strain CHIK-BD1586 envelope protein E1 gene, partial cds']
#
#
# gi|403309712|gb|JN974183.1| Chikungunya virus isolate NIV-112153 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|403309710|gb|JN974182.1| Chikungunya virus isolate NIV-112156 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|403309708|gb|JN974181.1| Chikungunya virus isolate NIV-112162 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|403309706|gb|JN974180.1| Chikungunya virus isolate NIV-112150 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|403309704|gb|JN974179.1| Chikungunya virus isolate NIV-112163 nonstructural protein 1 gene, partial cds
# []
#
#
# gi|2107900031|gb|MT787024.1| Chikungunya virus strain SADS E2 gene, partial cds
# []
#
#
# gi|2095906856|gb|MW979341.1| Chikungunya virus strain PAC269 structural polyprotein gene, partial cds
# ['gi|2095906854|gb|MW979340.1| Chikungunya virus strain PAC195 structural polyprotein gene, partial cds', 'gi|2095906842|gb|MW979334.1| Chikungunya virus strain SLZ118 structural polyprotein gene, partial cds', 'gi|2095906840|gb|MW979333.1| Chikungunya virus strain SLZ117 structural polyprotein gene, partial cds', 'gi|2095906838|gb|MW979332.1| Chikungunya virus strain SLZ60 structural polyprotein gene, partial cds', 'gi|1896069189|gb|MT075546.1| Chikungunya virus isolate CHIKV/Homo_sapiens/Brazil/2016/12 structural polyprotein gene, partial cds']
#
#
# gi|2076214174|dbj|LC603843.1| Chikungunya virus MLD19-77 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214172|dbj|LC603842.1| Chikungunya virus MLD19-76 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214170|dbj|LC603841.1| Chikungunya virus MLD19-75 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214168|dbj|LC603840.1| Chikungunya virus MLD19-74 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214166|dbj|LC603839.1| Chikungunya virus MLD19-72 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214164|dbj|LC603838.1| Chikungunya virus MLD19-71 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214162|dbj|LC603837.1| Chikungunya virus MLD19-70 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214160|dbj|LC603836.1| Chikungunya virus MLD19-69 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214158|dbj|LC603835.1| Chikungunya virus MLD19-64 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214156|dbj|LC603834.1| Chikungunya virus MLD19-62 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214154|dbj|LC603833.1| Chikungunya virus MLD19-60 gene for structural polyprotein, partial cds
# []
#
#
# gi|2076214152|dbj|LC603832.1| Chikungunya virus MLD19-57 gene for structural polyprotein, partial cds
# []
# ...
# []
#
#
# gi|269947938|emb|HC083927.1| Sequence 166 from Patent WO2009131683
# []
#
#
# gi|269947937|emb|HC083926.1| Sequence 165 from Patent WO2009131683
# []
#
#
# gi|269947936|emb|HC083925.1| Sequence 164 from Patent WO2009131683
# []
#
#
# gi|269947935|emb|HC083924.1| Sequence 163 from Patent WO2009131683
# []
#
#
# gi|269947934|emb|HC083923.1| Sequence 162 from Patent WO2009131683
# []
#
#
# gi|269947933|emb|HC083922.1| Sequence 161 from Patent WO2009131683
# []
#
#
# gi|269947932|emb|HC083921.1| Sequence 160 from Patent WO2009131683
# []
#
#
# gi|269947931|emb|HC083920.1| Sequence 159 from Patent WO2009131683
# []
#
#
# gi|269947930|emb|HC083919.1| Sequence 158 from Patent WO2009131683
# []
#
#
# gi|269947929|emb|HC083918.1| Sequence 157 from Patent WO2009131683
# []
#
#
# gi|269947928|emb|HC083917.1| Sequence 156 from Patent WO2009131683
# []
#
#
# gi|269947927|emb|HC083916.1| Sequence 155 from Patent WO2009131683
# []
#
#
# gi|269947926|emb|HC083915.1| Sequence 154 from Patent WO2009131683
# []
#
#
# gi|269947925|emb|HC083914.1| Sequence 153 from Patent WO2009131683
# []
#
#
# gi|269947924|emb|HC083913.1| Sequence 152 from Patent WO2009131683
# []
#
#
# gi|269947923|emb|HC083912.1| Sequence 151 from Patent WO2009131683
# []
#
#
# gi|269947922|emb|HC083911.1| Sequence 150 from Patent WO2009131683
# []
#
#
# gi|269947921|emb|HC083910.1| Sequence 149 from Patent WO2009131683
# []
#
#
# gi|269947920|emb|HC083909.1| Sequence 148 from Patent WO2009131683
# []
#
#
# gi|269947919|emb|HC083908.1| Sequence 147 from Patent WO2009131683
# []
#
#
# gi|269947918|emb|HC083907.1| Sequence 146 from Patent WO2009131683
# []
#
#
# gi|269947917|emb|HC083906.1| Sequence 145 from Patent WO2009131683
# []
#
#
# gi|269947916|emb|HC083905.1| Sequence 144 from Patent WO2009131683
# []
#
#
# gi|269947915|emb|HC083904.1| Sequence 143 from Patent WO2009131683
# []
#
#
# gi|269947914|emb|HC083903.1| Sequence 142 from Patent WO2009131683
# []
#
#
# gi|269947913|emb|HC083902.1| Sequence 141 from Patent WO2009131683
# []
#
#
# gi|269947912|emb|HC083901.1| Sequence 140 from Patent WO2009131683
# []
#
#
# gi|269947911|emb|HC083900.1| Sequence 139 from Patent WO2009131683
# []
#
#
# gi|269947910|emb|HC083899.1| Sequence 138 from Patent WO2009131683
# []
#
#
# gi|269947909|emb|HC083898.1| Sequence 137 from Patent WO2009131683
# []
#
#
# gi|269947908|emb|HC083897.1| Sequence 136 from Patent WO2009131683
# []
#
#
# gi|269947907|emb|HC083896.1| Sequence 135 from Patent WO2009131683
# []
#
#
# gi|269947906|emb|HC083895.1| Sequence 134 from Patent WO2009131683
# []
#
#
# gi|269947905|emb|HC083894.1| Sequence 133 from Patent WO2009131683
# []
#
#
# gi|269947904|emb|HC083893.1| Sequence 132 from Patent WO2009131683
# []
#
#
# gi|269947903|emb|HC083892.1| Sequence 131 from Patent WO2009131683
# []
#
#
# gi|269947882|emb|HC083871.1| Sequence 110 from Patent WO2009131683
# []
#
#
# gi|269947881|emb|HC083870.1| Sequence 109 from Patent WO2009131683
# []
#
#
# gi|269947880|emb|HC083869.1| Sequence 108 from Patent WO2009131683
# []
#
#
# gi|269947879|emb|HC083868.1| Sequence 107 from Patent WO2009131683
# []
#
#
# gi|269947878|emb|HC083867.1| Sequence 106 from Patent WO2009131683
# []
#
#
# gi|269947877|emb|HC083866.1| Sequence 105 from Patent WO2009131683
# []
#
#
# gi|269947876|emb|HC083865.1| Sequence 104 from Patent WO2009131683
# []
#
#
# gi|269947875|emb|HC083864.1| Sequence 103 from Patent WO2009131683
# []
#
#
# gi|269947874|emb|HC083863.1| Sequence 102 from Patent WO2009131683
# []
#
#
# gi|269947873|emb|HC083862.1| Sequence 101 from Patent WO2009131683
# []
#
#
# gi|269947872|emb|HC083861.1| Sequence 100 from Patent WO2009131683
# []
#
#
# gi|269947871|emb|HC083860.1| Sequence 99 from Patent WO2009131683
# []
#
#
# gi|269947870|emb|HC083859.1| Sequence 98 from Patent WO2009131683
# []
#
#
# gi|269947869|emb|HC083858.1| Sequence 97 from Patent WO2009131683
# []
#
#
# gi|269947868|emb|HC083857.1| Sequence 96 from Patent WO2009131683
# []
#
#
# gi|269947867|emb|HC083856.1| Sequence 95 from Patent WO2009131683
# []
#
#
# gi|269947866|emb|HC083855.1| Sequence 94 from Patent WO2009131683
# []
#
#
# gi|269947865|emb|HC083854.1| Sequence 93 from Patent WO2009131683
# []
#
#
# gi|269947864|emb|HC083853.1| Sequence 92 from Patent WO2009131683
# []
#
#
# gi|269947863|emb|HC083852.1| Sequence 91 from Patent WO2009131683
# []
#
#
# gi|269947861|emb|HC083850.1| Sequence 89 from Patent WO2009131683
# []
#
#
# gi|269947860|emb|HC083849.1| Sequence 88 from Patent WO2009131683
# []
#
#
# gi|269947859|emb|HC083848.1| Sequence 87 from Patent WO2009131683
# []
#
#
# gi|269947858|emb|HC083847.1| Sequence 86 from Patent WO2009131683
# []
#
#
# gi|269947857|emb|HC083846.1| Sequence 85 from Patent WO2009131683
# []
#
#
# gi|269947856|emb|HC083845.1| Sequence 84 from Patent WO2009131683
# []
#
#
# gi|269947855|emb|HC083844.1| Sequence 83 from Patent WO2009131683
# []
#
#
# gi|269947854|emb|HC083843.1| Sequence 82 from Patent WO2009131683
# []
#
#
# gi|269947853|emb|HC083842.1| Sequence 81 from Patent WO2009131683
# []
#
#
# gi|269947852|emb|HC083841.1| Sequence 80 from Patent WO2009131683
# []
#
#
# gi|269947851|emb|HC083840.1| Sequence 79 from Patent WO2009131683
# []
#
#
# gi|269947850|emb|HC083839.1| Sequence 78 from Patent WO2009131683
# []
#
#
# gi|269947849|emb|HC083838.1| Sequence 77 from Patent WO2009131683
# []
#
#
# gi|269947784|emb|HC083837.1| Sequence 76 from Patent WO2009131683
# []
#
#
# gi|269947768|emb|HC083836.1| Sequence 75 from Patent WO2009131683
# []
#
#
# gi|269947767|emb|HC083835.1| Sequence 74 from Patent WO2009131683
# []
#
#
# gi|269947766|emb|HC083834.1| Sequence 73 from Patent WO2009131683
# []
#
#
# gi|269947765|emb|HC083833.1| Sequence 72 from Patent WO2009131683
# []
#
#
# gi|269947764|emb|HC083832.1| Sequence 71 from Patent WO2009131683
# []
#
#
# gi|269947763|emb|HC083831.1| Sequence 70 from Patent WO2009131683
# []
#
#
# gi|269947762|emb|HC083830.1| Sequence 69 from Patent WO2009131683
# []
#
#
# gi|269947761|emb|HC083829.1| Sequence 68 from Patent WO2009131683
# []
#
#
# gi|269947760|emb|HC083828.1| Sequence 67 from Patent WO2009131683
# []
#
#
# gi|269947759|emb|HC083827.1| Sequence 66 from Patent WO2009131683
# []
#
#
# gi|269947758|emb|HC083826.1| Sequence 65 from Patent WO2009131683
# []
#
#
# gi|269947757|emb|HC083825.1| Sequence 64 from Patent WO2009131683
# []
#
#
# gi|269947756|emb|HC083824.1| Sequence 63 from Patent WO2009131683
# []
#
#
# gi|269947755|emb|HC083823.1| Sequence 62 from Patent WO2009131683
# []
#
#
# gi|269947754|emb|HC083822.1| Sequence 61 from Patent WO2009131683
# []
#
#
# gi|269947753|emb|HC083821.1| Sequence 60 from Patent WO2009131683
# []
#
#
# gi|269947752|emb|HC083820.1| Sequence 59 from Patent WO2009131683
# []
#
#
# gi|269947751|emb|HC083819.1| Sequence 58 from Patent WO2009131683
# []
#
#
# gi|269947750|emb|HC083818.1| Sequence 57 from Patent WO2009131683
# []
#
#
# gi|269947749|emb|HC083817.1| Sequence 56 from Patent WO2009131683
# []
#
#
# gi|269947748|emb|HC083816.1| Sequence 55 from Patent WO2009131683
# []
#
#
# gi|269947747|emb|HC083815.1| Sequence 54 from Patent WO2009131683
# []
#
#
# gi|269947746|emb|HC083814.1| Sequence 53 from Patent WO2009131683
# []
#
#
# gi|269947745|emb|HC083813.1| Sequence 52 from Patent WO2009131683
# []
#
#
# gi|269947744|emb|HC083812.1| Sequence 51 from Patent WO2009131683
# []
#
#
# gi|269947743|emb|HC083811.1| Sequence 50 from Patent WO2009131683
# []
#
#
# gi|269947742|emb|HC083810.1| Sequence 49 from Patent WO2009131683
# []
#
#
# gi|269947741|emb|HC083809.1| Sequence 48 from Patent WO2009131683
# []
#
#
# gi|269947740|emb|HC083808.1| Sequence 47 from Patent WO2009131683
# []
#
#
# gi|269947739|emb|HC083807.1| Sequence 46 from Patent WO2009131683
# []
#
#
# gi|269947738|emb|HC083806.1| Sequence 45 from Patent WO2009131683
# []
#
#
# gi|269947737|emb|HC083805.1| Sequence 44 from Patent WO2009131683
# []
#
#
# gi|269947736|emb|HC083804.1| Sequence 43 from Patent WO2009131683
# []
#
#
# gi|269947735|emb|HC083803.1| Sequence 42 from Patent WO2009131683
# []
#
#
# gi|269947734|emb|HC083802.1| Sequence 41 from Patent WO2009131683
# []
#
#
# gi|269947733|emb|HC083801.1| Sequence 40 from Patent WO2009131683
# []
#
#
# gi|269947732|emb|HC083800.1| Sequence 39 from Patent WO2009131683
# []
#
#
# gi|269947731|emb|HC083799.1| Sequence 38 from Patent WO2009131683
# []
#
#
# gi|269947730|emb|HC083798.1| Sequence 37 from Patent WO2009131683
# []
#
#
# gi|269947729|emb|HC083797.1| Sequence 36 from Patent WO2009131683
# []
#
#
# gi|269947728|emb|HC083796.1| Sequence 35 from Patent WO2009131683
# []
#
#
# gi|269947727|emb|HC083795.1| Sequence 34 from Patent WO2009131683
# []
#
#
# gi|269947726|emb|HC083794.1| Sequence 33 from Patent WO2009131683
# []
#
#
# gi|269947725|emb|HC083793.1| Sequence 32 from Patent WO2009131683
# []
#
#
# gi|269947724|emb|HC083792.1| Sequence 31 from Patent WO2009131683
# []
#
#
# gi|269947723|emb|HC083791.1| Sequence 30 from Patent WO2009131683
# []
#
#
# gi|269947722|emb|HC083790.1| Sequence 29 from Patent WO2009131683
# []
#
#
# gi|269947721|emb|HC083789.1| Sequence 28 from Patent WO2009131683
# []
#
#
# gi|269947720|emb|HC083788.1| Sequence 27 from Patent WO2009131683
# []
#
#
# gi|269947719|emb|HC083787.1| Sequence 26 from Patent WO2009131683
# []
#
#
# gi|269947718|emb|HC083786.1| Sequence 25 from Patent WO2009131683
# []
#
#
# gi|269947717|emb|HC083785.1| Sequence 24 from Patent WO2009131683
# []
#
#
# gi|269947716|emb|HC083784.1| Sequence 23 from Patent WO2009131683
# []
#
#
# gi|269947715|emb|HC083783.1| Sequence 22 from Patent WO2009131683
# []
#
#
# gi|269947714|emb|HC083782.1| Sequence 21 from Patent WO2009131683
# []
#
#
# gi|269947713|emb|HC083781.1| Sequence 20 from Patent WO2009131683
# []
#
#
# gi|269947712|emb|HC083780.1| Sequence 19 from Patent WO2009131683
# []
#
#
# gi|269947711|emb|HC083779.1| Sequence 18 from Patent WO2009131683
# []
#
#
# gi|269947710|emb|HC083778.1| Sequence 17 from Patent WO2009131683
# []
#
#
# gi|269947709|emb|HC083777.1| Sequence 16 from Patent WO2009131683
# []
#
#
# gi|269947708|emb|HC083776.1| Sequence 15 from Patent WO2009131683
# []
#
#
# gi|269947707|emb|HC083775.1| Sequence 14 from Patent WO2009131683
# []
#
#
# gi|269947706|emb|HC083774.1| Sequence 13 from Patent WO2009131683
# []
#
#
# gi|269947705|emb|HC083773.1| Sequence 12 from Patent WO2009131683
# []
#
#
# gi|269947704|emb|HC083772.1| Sequence 11 from Patent WO2009131683
# []
#
#
# gi|269947703|emb|HC083771.1| Sequence 10 from Patent WO2009131683
# []
#
#
# gi|269947702|emb|HC083770.1| Sequence 9 from Patent WO2009131683
# []
#
#
# gi|269947701|emb|HC083769.1| Sequence 8 from Patent WO2009131683
# []
#
#
# gi|269947700|emb|HC083768.1| Sequence 7 from Patent WO2009131683
# []
#
#
# gi|269947699|emb|HC083767.1| Sequence 6 from Patent WO2009131683
# []
#
#
# gi|269947698|emb|HC083766.1| Sequence 5 from Patent WO2009131683
# []
#
#
# gi|269947697|emb|HC083765.1| Sequence 4 from Patent WO2009131683
# []
#
#
# gi|269947696|emb|HC083764.1| Sequence 3 from Patent WO2009131683
# []
#
#
# gi|269947695|emb|HC083763.1| Sequence 2 from Patent WO2009131683
# []
#
#
# gi|269947694|emb|HC083762.1| Sequence 1 from Patent WO2009131683
# []
#
#
# gi|258644146|emb|FN295495.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/6008, genomic RNA
# []
#
#
# gi|258644144|emb|FN295494.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/2561, genomic RNA
# []
#
#
# gi|258644142|emb|FN295493.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/0539, genomic RNA
# []
#
#
# gi|258644140|emb|FN295492.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/7913, genomic RNA
# []
#
#
# gi|258644138|emb|FN295491.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/5369, genomic RNA
# []
#
#
# gi|258644136|emb|FN295490.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/6000, genomic RNA
# []
#
#
# gi|258644132|emb|FN295488.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/2868, genomic RNA
# []
#
#
# gi|258644128|emb|FN295486.1| Chikungunya virus partial gene for structural polyprotein, envelope protein E1 region, isolate MY/08/066, genomic RNA
# []
#
#
# gi|236164589|emb|GN351091.1| Sequence 855 from Patent WO2007130519
# []
#
#
# gi|236164587|emb|GN351090.1| Sequence 854 from Patent WO2007130519
# []
#
#
# gi|236164585|emb|GN351089.1| Sequence 853 from Patent WO2007130519
# []
#
#
# gi|236164583|emb|GN351088.1| Sequence 852 from Patent WO2007130519
# []
#
#
# gi|236164581|emb|GN351087.1| Sequence 851 from Patent WO2007130519
# []
#
#
# gi|236164579|emb|GN351086.1| Sequence 850 from Patent WO2007130519
# []
#
#
# gi|236164577|emb|GN351085.1| Sequence 849 from Patent WO2007130519
# []
#
#
# gi|236164575|emb|GN351084.1| Sequence 848 from Patent WO2007130519
# []
#
#
# gi|236164573|emb|GN351083.1| Sequence 847 from Patent WO2007130519
# []
#
#
# gi|236164571|emb|GN351082.1| Sequence 846 from Patent WO2007130519
# []
#
#
# gi|229613267|emb|GN349263.1| Sequence 14 from Patent WO2009044085
# []
#
#
# gi|229613266|emb|GN349262.1| Sequence 13 from Patent WO2009044085
# []
#
#
# gi|229613265|emb|GN349261.1| Sequence 12 from Patent WO2009044085
# []
#
#
# gi|229613264|emb|GN349260.1| Sequence 11 from Patent WO2009044085
# []
#
#
# gi|229613263|emb|GN349259.1| Sequence 10 from Patent WO2009044085
# []
#
#
# gi|229613262|emb|GN349258.1| Sequence 9 from Patent WO2009044085
# []
#
#
# gi|229613261|emb|GN349257.1| Sequence 8 from Patent WO2009044085
# []
#
#
# gi|229613260|emb|GN349256.1| Sequence 7 from Patent WO2009044085
# []
#
#
# gi|229613259|emb|GN349255.1| Sequence 6 from Patent WO2009044085
# []
#
#
# gi|229613258|emb|GN349254.1| Sequence 5 from Patent WO2009044085
# []
#
#
# gi|229613257|emb|GN349253.1| Sequence 4 from Patent WO2009044085
# []
#
#
# gi|229613256|emb|GN349252.1| Sequence 3 from Patent WO2009044085
# []
#
#
# gi|229613255|emb|GN349251.1| Sequence 2 from Patent WO2009044085
# []
#
#
# gi|229613254|emb|GN349250.1| Sequence 1 from Patent WO2009044085
# []
#
#
# gi|218101263|emb|GM839469.1| Sequence 98 from Patent EP1986009
# []
#
#
# gi|218101262|emb|GM839468.1| Sequence 97 from Patent EP1986009
# []
#
#
# gi|218101261|emb|GM839467.1| Sequence 96 from Patent EP1986009
# []
# gi|218101259|emb|GM839466.1| Sequence 95 from Patent EP1986009
# []
#
#
# gi|218101230|emb|GM839465.1| Sequence 94 from Patent EP1986009
# []
#
#
# gi|218101229|emb|GM839464.1| Sequence 93 from Patent EP1986009
# []
#
#
# gi|218101227|emb|GM839463.1| Sequence 92 from Patent EP1986009
# []
#
#
# gi|218101226|emb|GM839462.1| Sequence 91 from Patent EP1986009
# []
#
#
# gi|218101225|emb|GM839461.1| Sequence 90 from Patent EP1986009
# []
#
#
# gi|218101224|emb|GM839460.1| Sequence 89 from Patent EP1986009
# []
#
#
# gi|218101223|emb|GM839459.1| Sequence 88 from Patent EP1986009
# []
#
#
# gi|218101222|emb|GM839458.1| Sequence 87 from Patent EP1986009
# []
#
#
# gi|218101218|emb|GM839453.1| Sequence 82 from Patent EP1986009
# []
#
#
# gi|218101217|emb|GM839452.1| Sequence 81 from Patent EP1986009
# []
#
#
# gi|218101216|emb|GM839385.1| Sequence 14 from Patent EP1986009
# []
#
#
# gi|218101215|emb|GM839384.1| Sequence 13 from Patent EP1986009
# []
#
#
# gi|218101214|emb|GM839383.1| Sequence 12 from Patent EP1986009
# []
#
#
# gi|218101213|emb|GM839382.1| Sequence 11 from Patent EP1986009
# []
#
#
# gi|113927300|emb|AM397009.1| Chikungunya virus partial mRNA for structural protein E1 (E1 gene), isolate MY/0306/BP37437, genomic RNA
# []
#
#
# gi|113927298|emb|AM397008.1| Chikungunya virus partial mRNA for structural protein E1 (E1 gene), isolate MY/0306/BP37350, genomic RNA
# []
#
#
# gi|113927296|emb|AM397007.1| Chikungunya virus partial mRNA for structural protein E1 (E1 gene), isolate MY/0306/BP34198, genomic RNA
# []
#
#
# gi|113927294|emb|AM397006.1| Chikungunya virus partial mRNA for structural protein E1 (E1 gene), isolate MY/0306/BP37352, genomic RNA
# []
#
#
# gi|113927292|emb|AM397005.1| Chikungunya virus partial mRNA for structural protein E1 (E1 gene), isolate MY/0306/BP37348, genomic RNA
# []
#
#
# gi|113927290|emb|AM397004.1| Chikungunya virus partial mRNA for structural protein E2 (E2 gene), isolate MY/0306/BP37437, genomic RNA
# []
#
#
# gi|113927288|emb|AM397003.1| Chikungunya virus partial mRNA for structural protein E2 (E2 gene), isolate MY/0306/BP37350, genomic RNA
# []
#
#
# gi|113927286|emb|AM397002.1| Chikungunya virus partial mRNA for structural protein E2 (E2 gene), isolate MY/0306/BP34198, genomic RNA
# []
#
#
# gi|113927284|emb|AM397001.1| Chikungunya virus partial mRNA for structural protein E2 (E2 gene), isolate MY/0306/BP37352, genomic RNA
# []
#
#
# gi|113927282|emb|AM397000.1| Chikungunya virus partial mRNA for structural protein E2 (E2 gene), isolate MY/0306/BP37348, genomic RNA
# []
#
#
# gi|2586389|gb|AF023283.1| Chikungunya virus S27 3'UTR
# []

# %%
print(len(result_df.index))
print(len(result_dict.keys()))

print(len(result_df.index) / len(result_dict.keys()))
# Out:
# 6947
# 4132
# 1.6812681510164569
