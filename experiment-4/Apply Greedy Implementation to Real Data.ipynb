# %%
from Bio import SeqIO
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %matplotlib inline

# %%
def greedy_partition(df, threshold):

    ignore_index = []
    tally_dict = {}

    debug=False

    for row_id in df.index:

        if debug:
            print(row_id)
            print(ignore_index)

        # if we've already assigned this index as a child, don't need to consider it's row
        if not(row_id in ignore_index):

            # get the full dataframe row for this sample
            this_row_init = df.loc[row_id]  

            # remove columns that are already children of other nodes
            this_row = this_row_init.drop(labels = ignore_index)  
            #print(this_row)
            if debug:
                print(this_row_init.shape)
                print(this_row.shape)

            # children of this node are those with values greather than the threshold...
            children = list(this_row[this_row > threshold].index)
            children_filtered = [i for i in children if i != row_id ] #...not inlucding the node name itself

            if debug:
                print("len of children_filtered: " + str(len(children_filtered)) + '\n\n')

            # add the node + children to the dictionary, 
            # then add node + children to the set to ignore in future iterations
            tally_dict[row_id] = children_filtered
            ignore_index += children_filtered
            ignore_index += [row_id]

    return(tally_dict)

# %%
# taxon-specific data dumps are downloaded from GenBank using the corresponding query, written to .fasta, 
# ... and put in a location available to this script

#this_dump = "moraxellacatarhalis_29497_dump"
#this_dump = "candidaauris_498019_dump"
this_dump = "mpox_10244_dump"
#this_dump = "rhinovirusc_463676_dump"
#this_dump = "chkv_txid37124_dump"

# %%
# Run Sourmash on the input fasta containing all accessions for that species

K = 31
ST = 1000
    
start = time.time()

! mkdir {this_dump}
! rm cmp*;
! rm *sig;
! sourmash sketch dna -p k={K},scaled={ST} --singleton {this_dump}.fasta;
! sourmash compare *.sig --containment -o {this_dump}/cmp.dist --csv {this_dump}/cmp.csv;
! mv {this_dump}.fasta.sig {this_dump}

end = time.time()
elapsed = end - start
# Out:
# mkdir: mpox_10244_dump: File exists
# zsh:1: no matches found: cmp*
# zsh:1: no matches found: *sig
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# computing signatures for files: mpox_10244_dump.fasta
# Computing a total of 1 signature(s) for each input.
# calculated 5452 signatures for 5452 sequences in mpox_10244_dump.fasta
# saved 5452 signature(s) to 'mpox_10244_dump.fasta.sig'. Note: signature license is CC0.
#
# == This is sourmash version 4.6.1. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 5452 signatures total.
#
# min similarity in matrix: 0.000
# saving labels to: mpox_10244_dump/cmp.dist.labels.txt
# saving comparison matrix to: mpox_10244_dump/cmp.dist
# WARNING: size estimation for at least one of these sketches may be inaccurate. ANI values will be set to 1 for these comparisons.

# %%
# Read in the sourmash results and apply greedy clustering to generate the clustered result
result_df = pd.read_csv(this_dump + "/cmp.csv")
result_df.index = result_df.columns
result_df.shape

result_dict = greedy_partition(result_df, .6) # do greedy clustering

# %%
# Write out the clustered result for inspection (via BLAST, etc)
len_of_key_pair = []
for key in result_dict:
    print(key)
    print(result_dict[key])
    print('\n')
    len_of_key_pair.append(len(result_dict[key]))
# Out:
# OQ503835.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00439/2022, partial genome
# ['OQ503834.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00438/2022, partial genome', 'OQ503833.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00445/2022, partial genome', 'OQ503811.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00437/2022, partial genome', 'OQ503810.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00436/2022, partial genome', 'OQ503809.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00435/2022, partial genome', 'OQ503808.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00434/2022, partial genome', 'OQ503807.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00433/2022, partial genome', 'OQ503806.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00432/2022, partial genome', 'OQ503805.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00431/2022, partial genome', 'OQ503804.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00430/2022, partial genome', 'OQ503803.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00429/2022, partial genome', 'OQ503802.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00428/2022, partial genome', 'OQ503801.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00427/2022, partial genome', 'OQ503796.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00444/2022, partial genome', 'OQ503795.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00443/2022, partial genome', 'OQ503794.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00442/2022, partial genome', 'OQ503793.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00441/2022, partial genome', 'OQ503789.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00455/2022, partial genome', 'OQ503788.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00454/2022, partial genome', 'OQ503787.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00453/2022, partial genome', 'OQ503786.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00452/2022, partial genome', 'OQ503785.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00451/2022, partial genome', 'OQ503784.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00450/2022, partial genome', 'OQ503782.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00448/2022, partial genome', 'OQ503781.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00447/2022, partial genome', 'OQ503780.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00440/2022, partial genome', 'OQ503779.1 Monkeypox virus isolate MPXV/Human/USA/CA-LACPHL-MA00446/2022, partial genome', 'LC756925.1 Monkeypox virus MPXV/human/Japan/Tokyo/2023/TKY220342 DNA, complete genome', 'LC756924.1 Monkeypox virus MPXV/human/Japan/Tokyo/2023/TKY220325 DNA, complete genome', 'LC756923.1 Monkeypox virus MPXV/human/Japan/Tokyo/2023/TKY220318 DNA, complete genome', 'LC756922.1 Monkeypox virus MPXV/human/Japan/Tokyo/2023/TKY220310 DNA, complete genome', 'OQ511287.1 Monkeypox virus isolate MPXV_USA_2022_OK0003, complete genome', 'OQ511286.1 Monkeypox virus isolate MPXV_USA_2022_OK0002, complete genome', 'OQ511285.1 Monkeypox virus isolate MPXV_USA_2022_OK0001, complete genome', 'OQ511284.1 Monkeypox virus isolate MPXV_USA_2022_OK0004, complete genome', 'OQ511277.1 Monkeypox virus isolate MPXV22/human/USA-IA-3, partial genome', 'OQ511276.1 Monkeypox virus isolate MPXV22/human/USA-IA-2, partial genome', 'OQ503778.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-100584/2022, complete genome', 'OQ503777.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-103817/2022, complete genome', 'OQ503776.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-107595/2022, complete genome', 'OQ503775.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-092397/2022, complete genome', 'OQ503774.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-090521/2022, complete genome', 'OQ503773.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-094428/2022, complete genome', 'OQ503772.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-091051/2022, complete genome', 'OQ503771.1 Monkeypox virus isolate MpxV/human/USA/WA-UW-092974/2022, complete genome', ...
#
#
# OQ417517.1 Monkeypox virus strain hMpxV/Hong Kong/VM23003519/2023 hemagglutinin (HA) gene, partial cds
# []
#
#
# pdb|8HG1|T Chain T, DNA (38-MER)
# []
#
#
# pdb|8HG1|P Chain P, DNA (25-MER)
# []
#
#
# OK573186.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573185.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573184.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573183.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573182.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573181.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573180.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573179.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573177.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573172.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573170.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573169.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573168.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573167.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573165.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573164.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573163.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573161.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573160.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573159.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573158.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573156.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573155.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573153.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573150.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573149.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573147.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573144.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573141.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573138.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573135.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573132.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# []
#
#
# OK573130.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_854 genomic sequence
# ['AY315883.1 Monkeypox virus strain CDC# v78-I-3945 soluble interferon-alpha/beta receptor gene, complete cds', 'AY315882.1 Monkeypox virus strain CDC# v70-I-187 soluble interferon-alpha/beta receptor gene, complete cds', 'AY315881.1 Monkeypox virus strain CDC# v97-I-004 soluble interferon-alpha/beta receptor gene, complete cds', 'AY315880.1 Monkeypox virus strain CDC# v79-I-005 soluble interferon-alpha/beta receptor gene, complete cds', 'AY315879.1 Monkeypox virus strain Congo 8 soluble interferon-alpha/beta receptor gene, complete cds']
#
#
# OK573104.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573103.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573102.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573101.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573100.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573099.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573098.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573097.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573096.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573095.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573094.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573093.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573091.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573090.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573089.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573088.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573087.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573086.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573085.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573084.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573083.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573081.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573080.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573078.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573077.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573075.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573074.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573072.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573071.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573070.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573068.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573067.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573065.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573064.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573062.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573061.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573060.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573059.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573058.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573056.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573055.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573051.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573050.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573049.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573047.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573043.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573042.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573040.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573034.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573028.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573027.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573020.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# OK573018.1 UNVERIFIED: Monkeypox virus FDA:FDAARGOS_855 genomic sequence
# []
#
#
# ON800897.1 Monkeypox virus isolate MPV-ARG003-2022 hemagglutinin (HA) gene, complete cds
# []
#
#
# ON720962.1 Monkeypox virus isolate MPV-ARG002-2022 hemagglutinin (HA) gene, complete cds
# []
#
#
# ON669283.1 Monkeypox virus isolate MPV-ARG001-2022 hemagglutinin (HA) gene, complete cds
# []
#
#
# ON631961.1 Monkeypox virus isolate MPxV/VIDRL01/2022 hemagglutinin (B2R) gene, partial cds
# []
#
#
# ON630332.1 Monkeypox virus isolate INMI-Pt1 hemagglutinin (HA) gene, complete cds
# []
#
#
# GN049036.1 Sequence 30 from Patent EP2028270
# []
#
#
# KY979131.1 Monkeypox virus isolate Janet Topoisomerase 1 gene, partial cds
# []
#
#
# KY979130.1 Monkeypox virus isolate Lola RNA polymerase gene, partial cds
# []
#
#
# LQ987474.1 Sequence 15 from Patent WO2013041853
# []
#
#
# MG906726.1 Monkeypox virus strain SierraLeone/2017 kelch-like protein gene, partial cds; dUTPase gene, complete cds; and hypothetical protein gene, partial cds
# []
#
#
# MF437052.1 Monkeypox virus A-type inclusion protein (A27L) gene, complete cds; and A-type inclusion protein (A28L) gene, partial cds
# []
#
#
# MF437051.1 Monkeypox virus hemagglutinin (HA) gene, partial cds
# []
#
#
# AY743600.1 Monkeypox virus strain Congo-8 B21R (B21R) gene, partial cds; and K1R (K1R) gene, complete cds
# []
#
#
# AY743598.1 Monkeypox virus strain Congo-8 D2L (D2L), D3R (D3R), D5R (D5R), D6L (D6L), D7L (D7L), D8L (D8L), D9L (D9L), D10L (D10L), D11L (D11L), D12L (D12L), D13L (D13L), D14L (D14L), D15L (D15L), D16L (D16L), D17L (D17L), D18L (D18L), D19L (D19L), P1L (P1L), P2L (P2L), O1L (O1L), O2L (O2L), C1L (C1L), and C2L (C2L) genes, complete cds
# ['AY548960.1 Monkeypox virus strain Zaire-1028 complement control-like protein (D15L) gene, complete cds', 'AY548959.1 Monkeypox virus strain CDC#v97-I-004 complement control-like protein (D15L) gene, complete cds', 'AY548958.1 Monkeypox virus strain CDC#v79-I-005 complement control-like protein (D15L) gene, complete cds', 'AF346406.1 Monkeypox virus Zaire-1977(77-0666) complement control-like protein (D15L) gene, complete cds', 'AF346405.1 Monkeypox virus Zaire-1996(96-17) complement control-like protein (D15L) gene, complete cds', 'AF346404.1 Monkeypox virus Congo-8 complement control-like protein (D15L) gene, complete cds', 'AB371721.1 Monkeypox virus D14L gene for complement control-like protein, complete cds, clone: Monkeypox virus Zr-599']
#
#
# AY298786.1 Callithrix jacchus orthopoxvirus tumor necrosis factor receptor II-like protein (crmB) gene, partial cds
# []
#
#
# AY298785.1 Callithrix jacchus orthopoxvirus hemagglutinin (HA) gene, complete cds; and unknown genes
# []
#
#
# AF375114.1 Monkeypox virus isolate mpv-wmp hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375113.1 Monkeypox virus isolate mpv-utc hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375112.1 Monkeypox virus isolate mvp-squir hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375111.1 Monkeypox virus isolate mpv-pvm hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375110.1 Monkeypox virus isolate mpv-pch hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375109.1 Monkeypox virus isolate mpv-mcc hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375108.1 Monkeypox virus isolate mpv-cpn hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375107.1 Monkeypox virus isolate mpv-cpcwn1 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375106.1 Monkeypox virus isolate mpv-cpcr hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375105.1 Monkeypox virus isolate mpv-cope hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375104.1 Monkeypox virus isolate mpv-congo8 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375103.1 Monkeypox virus isolate mpv-cncw-n1 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375102.1 Monkeypox virus isolate mpv-cncr hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375101.1 Monkeypox virus isolate mpv-96i16 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375100.1 Monkeypox virus isolate mpv-790005 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375099.1 Monkeypox virus isolate mpv-74-226 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375098.1 Monkeypox virus isolate mpv-3945 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375097.1 Monkeypox virus isolate mpv-266 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375096.1 Monkeypox virus isolate mpv-1997 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375095.1 Monkeypox virus isolate mpv-082 hemagglutinin (HA) gene, complete cds
# []
#
#
# AF375094.1 Monkeypox virus isolate mpv-0187 hemagglutinin (HA) gene, complete cds
# []
#
#
# HW795654.1 JP 2014526257-A/14: Probe
# []
#
#
# KP739446.1 Monkeypox virus isolate MPX0420 D1 (D1R) gene, complete cds
# ['KP739441.1 Monkeypox virus isolate MPX0338 D1 (D1R) gene, complete cds', 'KP739436.1 Monkeypox virus isolate MPX0297 D1 (D1R) gene, complete cds']
#
#
# DI408731.1 KR 1020140063780-A/15: PROBE WITH MULTIPLE TARGET REGION SPECIFICITY AND OF TRIPARTITE CHARACTER
# []
#
#
# JB071962.1 Sequence 2 from Patent EP2496699
# []
#
#
# JF799095.1 Monkeypox virus isolate IPB_MKP_Pygmy A-type inclusion protein gene, partial cds
# []
#
#
# JF792045.1 Monkeypox virus isolate IPB_MKP_Ban A-type inclusion protein gene, partial cds
# []
#
#
# AY102986.1 Monkeypox virus strain Zaire 77 secreted chemokine binding protein gene, complete cds
# []
#
#
# AY102985.1 Monkeypox virus strain Congo 8 secreted chemokine binding protein gene, complete cds
# []
#
#
# AF531453.1 Monkeypox virus strain CDC# V78-I-3945 secreted chemokine binding protein gene, complete cds
# []
#
#
# AF531452.1 Monkeypox virus strain CDC# V70-I-187 secreted chemokine binding protein gene, complete cds
# []
#
#
# AF531451.1 Monkeypox virus strain CDC# V97-I-004 secreted chemokine binding protein gene, complete cds
# []
#
#
# AF531450.1 Monkeypox virus strain CDC# v79-I-005 secreted chemokine binding protein gene, complete cds
# []
#
#
# AY264386.1 Monkeypox virus strain 007/01v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264385.1 Monkeypox virus strain 169/02c CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264384.1 Monkeypox virus strain Zaire 1028 CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264383.1 Monkeypox virus strain INRB#46 2000 CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264382.1 Monkeypox virus strain MSF#2 2001cC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264381.1 Monkeypox virus strain 006/02v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264380.1 Monkeypox virus strain 180/02c CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264379.1 Monkeypox virus strain 179/02c CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264378.1 Monkeypox virus strain 085/01v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264377.1 Monkeypox virus strain 171/02v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264376.1 Monkeypox virus strain 169/02v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264375.1 Monkeypox virus strain 138/02v CC-type chemokine binding protein gene, complete cds
# []
#
#
# AY264374.1 Monkeypox virus strain 127/02v CC-type chemokine binding protein gene, complete cds
# []
#
#
# L20437.1 Monkeypox virus VVE5R pseudogene, complete cds
# ['L20436.1 Monkeypox virus VVE5R pseudogene, complete cds', 'L20435.1 Monkeypox virus VVE5R pseudogene, complete cds']
#
#
# L20440.1 Monkeypox virus VVE5R pseudogene, complete cds
# []
#
#
# L20439.1 Monkeypox virus degenerate gene corresponding to VVE5R DNA sequence
# []
#
#
# FV537352.1 Modified Microbial Nucleic Acid
# ['FV537351.1 Modified Microbial Nucleic Acid']
#
#
# FV537350.1 Modified Microbial Nucleic Acid
# ['FV537349.1 Modified Microbial Nucleic Acid']
#
#
# AY160188.1 Monkeypox virus strain Zaire 79 A35R (A35R) gene, complete cds
# []
#
#
# DQ443525.1 Monkeypox virus isolate 159/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443524.1 Monkeypox virus isolate 180/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443523.1 Monkeypox virus isolate 138/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443522.1 Monkeypox virus isolate 125/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443521.1 Monkeypox virus isolate 111/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443520.1 Monkeypox virus isolate 04MPX020c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443519.1 Monkeypox virus isolate 04MPX018v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443518.1 Monkeypox virus isolate 04MPX017c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443517.1 Monkeypox virus isolate 04MPX013c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443516.1 Monkeypox virus isolate 04MPX004v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443515.1 Monkeypox virus isolate 04MPX003c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443514.1 Monkeypox virus isolate 04MPX002c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443513.1 Monkeypox virus isolate 004/01c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443512.1 Monkeypox virus isolate 001/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443511.1 Monkeypox virus isolate 196/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443510.1 Monkeypox virus isolate 017/03c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443509.1 Monkeypox virus isolate 223/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443508.1 Monkeypox virus isolate 194/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443507.1 Monkeypox virus isolate 184/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443506.1 Monkeypox virus isolate 016/03c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443505.1 Monkeypox virus isolate 195/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443504.1 Monkeypox virus clone 005/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443503.1 Monkeypox virus isolate 015/03c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443502.1 Monkeypox virus isolate 171/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443501.1 Monkeypox virus isolate 169/02c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443500.1 Monkeypox virus isolate 141/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443499.1 Monkeypox virus isolate 140/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443498.1 Monkeypox virus isolate 139/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443497.1 Monkeypox virus isolate 127/02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443496.1 Monkeypox virus isolate 093/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443495.1 Monkeypox virus isolate 085/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443494.1 Monkeypox virus isolate 056/03v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443493.1 Monkeypox virus isolate 053/03v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443492.1 Monkeypox virus isolate 04MPX100c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443491.1 Monkeypox virus isolate 04MPX099v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443490.1 Monkeypox virus isolate 04MPX097v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443489.1 Monkeypox virus isolate 04MPX094v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443488.1 Monkeypox virus isolate 04MPX093v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443487.1 Monkeypox virus isolate 04MPX011v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443486.1 Monkeypox virus isolate 038/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443485.1 Monkeypox virus isolate 036/01c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443484.1 Monkeypox virus isolate 034/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443483.1 Monkeypox virus isolate 014/03c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443482.1 Monkeypox virus isolate 009/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443481.1 Monkeypox virus isolate 007/01v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443480.1 Monkeypox virus isolate 006-02v hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443479.1 Monkeypox virus isolate 04MPX089c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443478.1 Monkeypox virus isolate 04MPX095c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443477.1 Monkeypox virus isolate 054/03c hemagglutinin (HA) gene, complete cds
# []
#
#
# DQ443476.1 Monkeypox virus isolate 04MPX096c hemagglutinin (HA) gene, complete cds
# []
#
#
# AY944032.1 Monkeypox virus isolate MPV03_cng hemagglutinin (HA) gene, complete cds
# []
#
#
# AY944031.1 Monkeypox virus isolate MPV61_walter reed hemagglutinin (HA) gene, complete cds
# []
#
#
# AY944030.1 Monkeypox virus isolate MPV03_man hemagglutinin (HA) gene, complete cds
# []
#
#
# DM466410.1 PPAR Activator
# []
#
#
# AY548962.1 Monkeypox virus strain CDC#v78-I-3945, partial sequence
# []
#
#
# AY548961.1 Monkeypox virus strain CDC#v70-I-187, partial sequence
# []
#
#
# K02025.1 Monkeypox virus thymidine kinase gene
# []
#
#
# GN354503.1 Sequence 4267 from Patent WO2007130519
# []
#
#
# GN354502.1 Sequence 4266 from Patent WO2007130519
# []
#
#
# GN354501.1 Sequence 4265 from Patent WO2007130519
# []
#
#
# GN354500.1 Sequence 4264 from Patent WO2007130519
# []
#
#
# GN354499.1 Sequence 4263 from Patent WO2007130519
# []
#
#
# GN354498.1 Sequence 4262 from Patent WO2007130519
# []
#
#
# GN354497.1 Sequence 4261 from Patent WO2007130519
# []
#
#
# GN354496.1 Sequence 4260 from Patent WO2007130519
# []
#
#
# GN354495.1 Sequence 4259 from Patent WO2007130519
# []
#
#
# GN354494.1 Sequence 4258 from Patent WO2007130519
# []
#
#
# M95534.1 Monkeypox virus DNA sequence
# []
#
#
# L20438.1 Monkeypox virus VVE5R gene related DNA sequence
# []
#
#
# AB371720.1 Monkeypox virus D10L gene for hypothetical protein, complete cds, clone: Monkeypox virus Zr-599
# []
#
#
# CS106430.1 Sequence 30 from Patent WO2005047458
# []
#
#
# CS064649.1 Sequence 76 from Patent WO2005030991
# []
#
#
# CS064631.1 Sequence 58 from Patent WO2005030991
# []
#
#
# CS064630.1 Sequence 57 from Patent WO2005030991
# []
#
#
# CS064584.1 Sequence 11 from Patent WO2005030991
# []
#
#
# X97855.1 Monkeypox virus gene encoding 32kDa adsorption protein
# []
#
#
# Z99052.1 Monkeypox virus ORF1R, strain Zaire 77-0666
# []
#
#
# AJ309910.1 Monkeypox Virus a13L ortholog gene for p8, strain Gabon
# []
#
#
# AJ315002.1 Monkeypox virus A36R gene for p43-50 protein, strain Z1
# []
#
#
# AJ315001.1 Monkeypox virus A36R gene for p43-50 protein, strain Copenhagen
# []
#
#
# AJ309909.1 Monkeypox Virus a13L ortholog gene for p8, strain Copenhagen
# []
#
#
# AJ404663.1 Monkeypox virus (strain Zaire 77-0666) ifnr gene for interferon-gamma receptor
# ['AJ404662.1 Monkeypox virus (strain Sierra Leone 70-0266) ifnr gene for interferon-gamma receptor']

# %%
# Compute the compression ratio = initial_size / current_size of DB

# sanity checking the calculations around compression ratio
len_of_key_pair.sort()
#print(sum(len_of_key_pair))
#print(len(result_df.index) - sum(len_of_key_pair))
#len_of_key_pair[-10:]

# compression ratio
print("initial count of accession: " + str(len(result_df.index)))
print("final count after clustering: " + str(len(result_dict.keys())))
print("compression ratio: " + str(len(result_df.index) / len(result_dict.keys())))
# Out:
# initial count of accession: 5452
# final count after clustering: 240
# compression ratio: 22.716666666666665

# %% [markdown]
# ### Take the clustered data and generate a new .fasta file of accessions

# %%
records = list(SeqIO.parse(this_dump + ".fasta", "fasta"))
new_dump_fasta = this_dump + '.new.fasta'
with open(new_dump_fasta, 'w') as f: 
    for r in records:
        seqid = r.description
        if seqid in result_dict.keys():
            f.write('>' + seqid + '\n' + str(r.seq) + '\n')
f.close()
